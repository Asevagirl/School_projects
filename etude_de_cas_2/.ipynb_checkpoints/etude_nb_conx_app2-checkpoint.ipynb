# %%
import os
from scipy.io import loadmat
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import Ridge  
from sklearn.linear_model import Lasso  
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR 
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
np.set_printoptions(precision=2, suppress=True)
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_predict

from sklearn import svm
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score 
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/compat/pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
#Variables et dimesionnalité
nb_AD = 28
nb_MCI = 22
nb_SCI = 22
Freqs= ['ALPHA', 'BETA', 'DELTA', 'THETA']
Seuils = [100, 70, 50, 30, 20, 10]
dataFolder = 'EpEn data/'

# %%
#Chargement des matricces des trois types des patients
x_AD = []
for i in range(1, nb_AD+1):
    x = {}
    for freq in Freqs:
        x[freq + '_100'] = loadmat(dataFolder + freq + '/' 
                                    + 'AD' + '/' 
                                    + str(i) + '.mat')[freq]
    x_AD.append(x)

x_MCI = []
for i in range(1, nb_MCI+1):
    x = {}
    for freq in Freqs:
        x[freq + '_100'] = loadmat(dataFolder + freq + '/' 
                                    + 'MCI' + '/' 
                                    + str(i) + '.mat')[freq]
    x_MCI.append(x)

x_SCI= []
for i in range(1, nb_SCI+1):
    x = {}
    for freq in Freqs:
        x[freq + '_100'] = loadmat(dataFolder + freq + '/' 
                                    + 'SCI' + '/' 
                                    + str(i) + '.mat')[freq]
    x_SCI.append(x)

# %%
#On étend les dictionaires aux 6 différents niveau de seuil
def get_percentile(x, seuil):
    y = x.copy()
    percentile_limit = np.percentile(x, 100 - seuil)
    y[y<percentile_limit] = 0
    return y


for i in range(nb_AD):
    for freq in Freqs:
        for seuil in Seuils:
            x_AD[i][freq+'_'+str(seuil)] = get_percentile(x_AD[i][str(freq)+'_100'], seuil)
            
for i in range(nb_MCI):
    for freq in Freqs:
        for seuil in Seuils:
            x_MCI[i][freq+'_'+str(seuil)] = get_percentile(x_MCI[i][str(freq)+'_100'], seuil)
            
for i in range(nb_SCI):
    for freq in Freqs:
        for seuil in Seuils:
            x_SCI[i][freq+'_'+str(seuil)] = get_percentile(x_SCI[i][str(freq)+'_100'], seuil)

# %%
sns.heatmap(x_AD[27]['ALPHA_100'])

# %%
def nb_connexions_electrode(array):
    connexions = []
    for i in range(array.shape[0]):
        connexion = 0
        for j in range(len(connexions)):
            if array[i, j]>0:
                connexion += 1
        connexions.append(connexion)
    return connexions


def variance_cdf(array):
    variance_list = []
    for i in range(array.shape[0]):
        cdf = np.cumsum(array[i, :])
        variance_list.append(np.var(cdf))
    return variance_list

def moyenne(array):
    moyennes = []
    for i in range(array.shape[0]):
        moyenne = array[i, :].mean()
        moyennes.append(moyenne)
    return moyennes

# %%
Var=[]
for freq in Freqs:
    for seuil in Seuils:
        Var.append(freq+'_'+str(seuil))

# %%
matrices_AD = {}
for var in Var:
    matrice=[]
    for i in range (len(x_AD)):
        t = nb_connexions_electrode(x_AD[i][var])
        matrice.append(t)
    matrices_AD[var]= matrice
    
matrices_MCI = {}
for var in Var:
    matrice=[]
    for i in range (len(x_MCI)):
        t = nb_connexions_electrode(x_MCI[i][var])
        matrice.append(t)
    matrices_MCI[var]= matrice
    

matrices_SCI = {}
for var in Var:
    matrice=[]
    for i in range (len(x_SCI)):
        t = nb_connexions_electrode(x_SCI[i][var])
        matrice.append(t)
    matrices_SCI[var]= matrice

# %%
Elec = ['Elec1', 'Elec2', 'Elec3', 'Elec4', 'Elec5', 'Elec6', 'Elec7', 'Elec8', 'Elec9', 'Elec10', 'Elec11', 'Elec12', 'Elec13', 'Elec14', 'Elec15', 'Elec16', 'Elec17', 'Elec18', 'Elec19', 'Elec20', 'Elec21', 'Elec22', 'Elec23', 'Elec24', 'Elec25', 'Elec26', 'Elec27', 'Elec28', 'Elec29', 'Elec30']

# %%
def dataframe_creator(array,names):
    x = pd.DataFrame(array,columns=names)
    return x

# %%
data_AD_ALPHA_100= dataframe_creator(matrices_AD['ALPHA_100'],Elec)
data_AD_ALPHA_70= dataframe_creator(matrices_AD['ALPHA_70'],Elec)
data_AD_ALPHA_50= dataframe_creator(matrices_AD['ALPHA_50'],Elec)
data_AD_ALPHA_30= dataframe_creator(matrices_AD['ALPHA_30'],Elec)
data_AD_ALPHA_20= dataframe_creator(matrices_AD['ALPHA_20'],Elec)
data_AD_ALPHA_10= dataframe_creator(matrices_AD['ALPHA_10'],Elec)
data_AD_BETA_100= dataframe_creator(matrices_AD['BETA_100'],Elec)
data_AD_BETA_70= dataframe_creator(matrices_AD['BETA_70'],Elec)
data_AD_BETA_50= dataframe_creator(matrices_AD['BETA_50'],Elec)
data_AD_BETA_30= dataframe_creator(matrices_AD['BETA_30'],Elec)
data_AD_BETA_20= dataframe_creator(matrices_AD['BETA_20'],Elec)
data_AD_BETA_10= dataframe_creator(matrices_AD['BETA_10'],Elec)
data_AD_DELTA_100= dataframe_creator(matrices_AD['DELTA_100'],Elec)
data_AD_DELTA_70= dataframe_creator(matrices_AD['DELTA_70'],Elec)
data_AD_DELTA_50= dataframe_creator(matrices_AD['DELTA_50'],Elec)
data_AD_DELTA_30= dataframe_creator(matrices_AD['DELTA_30'],Elec)
data_AD_DELTA_20= dataframe_creator(matrices_AD['DELTA_20'],Elec)
data_AD_DELTA_10= dataframe_creator(matrices_AD['DELTA_10'],Elec)
data_AD_THETA_100= dataframe_creator(matrices_AD['THETA_100'],Elec)
data_AD_THETA_70= dataframe_creator(matrices_AD['THETA_70'],Elec)
data_AD_THETA_50= dataframe_creator(matrices_AD['THETA_50'],Elec)
data_AD_THETA_30= dataframe_creator(matrices_AD['THETA_30'],Elec)
data_AD_THETA_20= dataframe_creator(matrices_AD['THETA_20'],Elec)
data_AD_THETA_10= dataframe_creator(matrices_AD['THETA_10'],Elec)

# %%
data_MCI_ALPHA_100= dataframe_creator(matrices_MCI['ALPHA_100'],Elec)
data_MCI_ALPHA_70= dataframe_creator(matrices_MCI['ALPHA_70'],Elec)
data_MCI_ALPHA_50= dataframe_creator(matrices_MCI['ALPHA_50'],Elec)
data_MCI_ALPHA_30= dataframe_creator(matrices_MCI['ALPHA_30'],Elec)
data_MCI_ALPHA_20= dataframe_creator(matrices_MCI['ALPHA_20'],Elec)
data_MCI_ALPHA_10= dataframe_creator(matrices_MCI['ALPHA_10'],Elec)
data_MCI_BETA_100= dataframe_creator(matrices_MCI['BETA_100'],Elec)
data_MCI_BETA_70= dataframe_creator(matrices_MCI['BETA_70'],Elec)
data_MCI_BETA_50= dataframe_creator(matrices_MCI['BETA_50'],Elec)
data_MCI_BETA_30= dataframe_creator(matrices_MCI['BETA_30'],Elec)
data_MCI_BETA_20= dataframe_creator(matrices_MCI['BETA_20'],Elec)
data_MCI_BETA_10= dataframe_creator(matrices_MCI['BETA_10'],Elec)
data_MCI_DELTA_100= dataframe_creator(matrices_MCI['DELTA_100'],Elec)
data_MCI_DELTA_70= dataframe_creator(matrices_MCI['DELTA_70'],Elec)
data_MCI_DELTA_50= dataframe_creator(matrices_MCI['DELTA_50'],Elec)
data_MCI_DELTA_30= dataframe_creator(matrices_MCI['DELTA_30'],Elec)
data_MCI_DELTA_20= dataframe_creator(matrices_MCI['DELTA_20'],Elec)
data_MCI_DELTA_10= dataframe_creator(matrices_MCI['DELTA_10'],Elec)
data_MCI_THETA_100= dataframe_creator(matrices_MCI['THETA_100'],Elec)
data_MCI_THETA_70= dataframe_creator(matrices_MCI['THETA_70'],Elec)
data_MCI_THETA_50= dataframe_creator(matrices_MCI['THETA_50'],Elec)
data_MCI_THETA_30= dataframe_creator(matrices_MCI['THETA_30'],Elec)
data_MCI_THETA_20= dataframe_creator(matrices_MCI['THETA_20'],Elec)
data_MCI_THETA_10= dataframe_creator(matrices_MCI['THETA_10'],Elec)

# %%
data_SCI_ALPHA_100= dataframe_creator(matrices_SCI['ALPHA_100'],Elec)
data_SCI_ALPHA_70= dataframe_creator(matrices_SCI['ALPHA_70'],Elec)
data_SCI_ALPHA_50= dataframe_creator(matrices_SCI['ALPHA_50'],Elec)
data_SCI_ALPHA_30= dataframe_creator(matrices_SCI['ALPHA_30'],Elec)
data_SCI_ALPHA_20= dataframe_creator(matrices_SCI['ALPHA_20'],Elec)
data_SCI_ALPHA_10= dataframe_creator(matrices_SCI['ALPHA_10'],Elec)
data_SCI_BETA_100= dataframe_creator(matrices_SCI['BETA_100'],Elec)
data_SCI_BETA_70= dataframe_creator(matrices_SCI['BETA_70'],Elec)
data_SCI_BETA_50= dataframe_creator(matrices_SCI['BETA_50'],Elec)
data_SCI_BETA_30= dataframe_creator(matrices_SCI['BETA_30'],Elec)
data_SCI_BETA_20= dataframe_creator(matrices_SCI['BETA_20'],Elec)
data_SCI_BETA_10= dataframe_creator(matrices_SCI['BETA_10'],Elec)
data_SCI_DELTA_100= dataframe_creator(matrices_SCI['DELTA_100'],Elec)
data_SCI_DELTA_70= dataframe_creator(matrices_SCI['DELTA_70'],Elec)
data_SCI_DELTA_50= dataframe_creator(matrices_SCI['DELTA_50'],Elec)
data_SCI_DELTA_30= dataframe_creator(matrices_SCI['DELTA_30'],Elec)
data_SCI_DELTA_20= dataframe_creator(matrices_SCI['DELTA_20'],Elec)
data_SCI_DELTA_10= dataframe_creator(matrices_SCI['DELTA_10'],Elec)
data_SCI_THETA_100= dataframe_creator(matrices_SCI['THETA_100'],Elec)
data_SCI_THETA_70= dataframe_creator(matrices_SCI['THETA_70'],Elec)
data_SCI_THETA_50= dataframe_creator(matrices_SCI['THETA_50'],Elec)
data_SCI_THETA_30= dataframe_creator(matrices_SCI['THETA_30'],Elec)
data_SCI_THETA_20= dataframe_creator(matrices_SCI['THETA_20'],Elec)
data_SCI_THETA_10= dataframe_creator(matrices_SCI['THETA_10'],Elec)

# %%
#datasets AD vs MCI
data_AD_MCI_ALPHA_100= pd.concat([data_AD_ALPHA_100,data_MCI_ALPHA_100])
data_AD_MCI_ALPHA_70= pd.concat([data_AD_ALPHA_70,data_MCI_ALPHA_70])
data_AD_MCI_ALPHA_50= pd.concat([data_AD_ALPHA_50,data_MCI_ALPHA_50])
data_AD_MCI_ALPHA_30= pd.concat([data_AD_ALPHA_30,data_MCI_ALPHA_30])
data_AD_MCI_ALPHA_20= pd.concat([data_AD_ALPHA_20,data_MCI_ALPHA_20])
data_AD_MCI_ALPHA_10= pd.concat([data_AD_ALPHA_10,data_MCI_ALPHA_10])
data_AD_MCI_BETA_100= pd.concat([data_AD_BETA_100,data_MCI_BETA_100])
data_AD_MCI_BETA_70= pd.concat([data_AD_BETA_70,data_MCI_BETA_70])
data_AD_MCI_BETA_50= pd.concat([data_AD_BETA_50,data_MCI_BETA_50])
data_AD_MCI_BETA_30= pd.concat([data_AD_BETA_30,data_MCI_BETA_30])
data_AD_MCI_BETA_20= pd.concat([data_AD_BETA_20,data_MCI_BETA_20])
data_AD_MCI_BETA_10= pd.concat([data_AD_BETA_10,data_MCI_BETA_10])
data_AD_MCI_DELTA_100= pd.concat([data_AD_DELTA_100,data_MCI_DELTA_100])
data_AD_MCI_DELTA_70= pd.concat([data_AD_DELTA_70,data_MCI_DELTA_70])
data_AD_MCI_DELTA_50= pd.concat([data_AD_DELTA_50,data_MCI_DELTA_50])
data_AD_MCI_DELTA_30= pd.concat([data_AD_DELTA_30,data_MCI_DELTA_30])
data_AD_MCI_DELTA_20= pd.concat([data_AD_DELTA_20,data_MCI_DELTA_20])
data_AD_MCI_DELTA_10= pd.concat([data_AD_DELTA_10,data_MCI_DELTA_10])
data_AD_MCI_THETA_100= pd.concat([data_AD_THETA_100,data_MCI_THETA_100])
data_AD_MCI_THETA_70= pd.concat([data_AD_THETA_70,data_MCI_THETA_70])
data_AD_MCI_THETA_50= pd.concat([data_AD_THETA_50,data_MCI_THETA_50])
data_AD_MCI_THETA_30= pd.concat([data_AD_THETA_30,data_MCI_THETA_30])
data_AD_MCI_THETA_20= pd.concat([data_AD_THETA_20,data_MCI_THETA_20])
data_AD_MCI_THETA_10= pd.concat([data_AD_THETA_10,data_MCI_THETA_10])

# %%
#Dataset split
X=data_AD_MCI_ALPHA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_100, X_test_data_AD_MCI_ALPHA_100, y_train_data_AD_MCI_ALPHA_100, y_test_data_AD_MCI_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_70, X_test_data_AD_MCI_ALPHA_70, y_train_data_AD_MCI_ALPHA_70, y_test_data_AD_MCI_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_50, X_test_data_AD_MCI_ALPHA_50, y_train_data_AD_MCI_ALPHA_50, y_test_data_AD_MCI_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_30, X_test_data_AD_MCI_ALPHA_30, y_train_data_AD_MCI_ALPHA_30, y_test_data_AD_MCI_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_20, X_test_data_AD_MCI_ALPHA_20, y_train_data_AD_MCI_ALPHA_20, y_test_data_AD_MCI_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_10, X_test_data_AD_MCI_ALPHA_10, y_train_data_AD_MCI_ALPHA_10, y_test_data_AD_MCI_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_100, X_test_data_AD_MCI_BETA_100, y_train_data_AD_MCI_BETA_100, y_test_data_AD_MCI_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_70, X_test_data_AD_MCI_BETA_70, y_train_data_AD_MCI_BETA_70, y_test_data_AD_MCI_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_50, X_test_data_AD_MCI_BETA_50, y_train_data_AD_MCI_BETA_50, y_test_data_AD_MCI_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_30, X_test_data_AD_MCI_BETA_30, y_train_data_AD_MCI_BETA_30, y_test_data_AD_MCI_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_20, X_test_data_AD_MCI_BETA_20, y_train_data_AD_MCI_BETA_20, y_test_data_AD_MCI_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_10, X_test_data_AD_MCI_BETA_10, y_train_data_AD_MCI_BETA_10, y_test_data_AD_MCI_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_AD_MCI_DELTA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_100, X_test_data_AD_MCI_DELTA_100, y_train_data_AD_MCI_DELTA_100, y_test_data_AD_MCI_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_70, X_test_data_AD_MCI_DELTA_70, y_train_data_AD_MCI_DELTA_70, y_test_data_AD_MCI_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_50, X_test_data_AD_MCI_DELTA_50, y_train_data_AD_MCI_DELTA_50, y_test_data_AD_MCI_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_30, X_test_data_AD_MCI_DELTA_30, y_train_data_AD_MCI_DELTA_30, y_test_data_AD_MCI_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_20, X_test_data_AD_MCI_DELTA_20, y_train_data_AD_MCI_DELTA_20, y_test_data_AD_MCI_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_10, X_test_data_AD_MCI_DELTA_10, y_train_data_AD_MCI_DELTA_10, y_test_data_AD_MCI_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_100, X_test_data_AD_MCI_THETA_100, y_train_data_AD_MCI_THETA_100, y_test_data_AD_MCI_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_70, X_test_data_AD_MCI_THETA_70, y_train_data_AD_MCI_THETA_70, y_test_data_AD_MCI_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_50, X_test_data_AD_MCI_THETA_50, y_train_data_AD_MCI_THETA_50, y_test_data_AD_MCI_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_30, X_test_data_AD_MCI_THETA_30, y_train_data_AD_MCI_THETA_30, y_test_data_AD_MCI_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_20, X_test_data_AD_MCI_THETA_20, y_train_data_AD_MCI_THETA_20, y_test_data_AD_MCI_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_10, X_test_data_AD_MCI_THETA_10, y_train_data_AD_MCI_THETA_10, y_test_data_AD_MCI_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
#datasets SCI vs MCI
data_SCI_MCI_ALPHA_100= pd.concat([data_SCI_ALPHA_100,data_MCI_ALPHA_100])
data_SCI_MCI_ALPHA_70= pd.concat([data_SCI_ALPHA_70,data_MCI_ALPHA_70])
data_SCI_MCI_ALPHA_50= pd.concat([data_SCI_ALPHA_50,data_MCI_ALPHA_50])
data_SCI_MCI_ALPHA_30= pd.concat([data_SCI_ALPHA_30,data_MCI_ALPHA_30])
data_SCI_MCI_ALPHA_20= pd.concat([data_SCI_ALPHA_20,data_MCI_ALPHA_20])
data_SCI_MCI_ALPHA_10= pd.concat([data_SCI_ALPHA_10,data_MCI_ALPHA_10])
data_SCI_MCI_BETA_100= pd.concat([data_SCI_BETA_100,data_MCI_BETA_100])
data_SCI_MCI_BETA_70= pd.concat([data_SCI_BETA_70,data_MCI_BETA_70])
data_SCI_MCI_BETA_50= pd.concat([data_SCI_BETA_50,data_MCI_BETA_50])
data_SCI_MCI_BETA_30= pd.concat([data_SCI_BETA_30,data_MCI_BETA_30])
data_SCI_MCI_BETA_20= pd.concat([data_SCI_BETA_20,data_MCI_BETA_20])
data_SCI_MCI_BETA_10= pd.concat([data_SCI_BETA_10,data_MCI_BETA_10])
data_SCI_MCI_DELTA_100= pd.concat([data_SCI_DELTA_100,data_MCI_DELTA_100])
data_SCI_MCI_DELTA_70= pd.concat([data_SCI_DELTA_70,data_MCI_DELTA_70])
data_SCI_MCI_DELTA_50= pd.concat([data_SCI_DELTA_50,data_MCI_DELTA_50])
data_SCI_MCI_DELTA_30= pd.concat([data_SCI_DELTA_30,data_MCI_DELTA_30])
data_SCI_MCI_DELTA_20= pd.concat([data_SCI_DELTA_20,data_MCI_DELTA_20])
data_SCI_MCI_DELTA_10= pd.concat([data_SCI_DELTA_10,data_MCI_DELTA_10])
data_SCI_MCI_THETA_100= pd.concat([data_SCI_THETA_100,data_MCI_THETA_100])
data_SCI_MCI_THETA_70= pd.concat([data_SCI_THETA_70,data_MCI_THETA_70])
data_SCI_MCI_THETA_50= pd.concat([data_SCI_THETA_50,data_MCI_THETA_50])
data_SCI_MCI_THETA_30= pd.concat([data_SCI_THETA_30,data_MCI_THETA_30])
data_SCI_MCI_THETA_20= pd.concat([data_SCI_THETA_20,data_MCI_THETA_20])
data_SCI_MCI_THETA_10= pd.concat([data_SCI_THETA_10,data_MCI_THETA_10])

# %%
#Dataset split
X=data_SCI_MCI_ALPHA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_100, X_test_data_SCI_MCI_ALPHA_100, y_train_data_SCI_MCI_ALPHA_100, y_test_data_SCI_MCI_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_70, X_test_data_SCI_MCI_ALPHA_70, y_train_data_SCI_MCI_ALPHA_70, y_test_data_SCI_MCI_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_50, X_test_data_SCI_MCI_ALPHA_50, y_train_data_SCI_MCI_ALPHA_50, y_test_data_SCI_MCI_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_30, X_test_data_SCI_MCI_ALPHA_30, y_train_data_SCI_MCI_ALPHA_30, y_test_data_SCI_MCI_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_20, X_test_data_SCI_MCI_ALPHA_20, y_train_data_SCI_MCI_ALPHA_20, y_test_data_SCI_MCI_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_10, X_test_data_SCI_MCI_ALPHA_10, y_train_data_SCI_MCI_ALPHA_10, y_test_data_SCI_MCI_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_100, X_test_data_SCI_MCI_BETA_100, y_train_data_SCI_MCI_BETA_100, y_test_data_SCI_MCI_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_70, X_test_data_SCI_MCI_BETA_70, y_train_data_SCI_MCI_BETA_70, y_test_data_SCI_MCI_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_50, X_test_data_SCI_MCI_BETA_50, y_train_data_SCI_MCI_BETA_50, y_test_data_SCI_MCI_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_30, X_test_data_SCI_MCI_BETA_30, y_train_data_SCI_MCI_BETA_30, y_test_data_SCI_MCI_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_20, X_test_data_SCI_MCI_BETA_20, y_train_data_SCI_MCI_BETA_20, y_test_data_SCI_MCI_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_10, X_test_data_SCI_MCI_BETA_10, y_train_data_SCI_MCI_BETA_10, y_test_data_SCI_MCI_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_SCI_MCI_DELTA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_100, X_test_data_SCI_MCI_DELTA_100, y_train_data_SCI_MCI_DELTA_100, y_test_data_SCI_MCI_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_70, X_test_data_SCI_MCI_DELTA_70, y_train_data_SCI_MCI_DELTA_70, y_test_data_SCI_MCI_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_50, X_test_data_SCI_MCI_DELTA_50, y_train_data_SCI_MCI_DELTA_50, y_test_data_SCI_MCI_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_30, X_test_data_SCI_MCI_DELTA_30, y_train_data_SCI_MCI_DELTA_30, y_test_data_SCI_MCI_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_20, X_test_data_SCI_MCI_DELTA_20, y_train_data_SCI_MCI_DELTA_20, y_test_data_SCI_MCI_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_10, X_test_data_SCI_MCI_DELTA_10, y_train_data_SCI_MCI_DELTA_10, y_test_data_SCI_MCI_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_100, X_test_data_SCI_MCI_THETA_100, y_train_data_SCI_MCI_THETA_100, y_test_data_SCI_MCI_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_70, X_test_data_SCI_MCI_THETA_70, y_train_data_SCI_MCI_THETA_70, y_test_data_SCI_MCI_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_50, X_test_data_SCI_MCI_THETA_50, y_train_data_SCI_MCI_THETA_50, y_test_data_SCI_MCI_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_30, X_test_data_SCI_MCI_THETA_30, y_train_data_SCI_MCI_THETA_30, y_test_data_SCI_MCI_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_20, X_test_data_SCI_MCI_THETA_20, y_train_data_SCI_MCI_THETA_20, y_test_data_SCI_MCI_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_10, X_test_data_SCI_MCI_THETA_10, y_train_data_SCI_MCI_THETA_10, y_test_data_SCI_MCI_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
#datasets SCI vs AD
data_SCI_AD_ALPHA_100= pd.concat([data_SCI_ALPHA_100,data_AD_ALPHA_100])
data_SCI_AD_ALPHA_70= pd.concat([data_SCI_ALPHA_70,data_AD_ALPHA_70])
data_SCI_AD_ALPHA_50= pd.concat([data_SCI_ALPHA_50,data_AD_ALPHA_50])
data_SCI_AD_ALPHA_30= pd.concat([data_SCI_ALPHA_30,data_AD_ALPHA_30])
data_SCI_AD_ALPHA_20= pd.concat([data_SCI_ALPHA_20,data_AD_ALPHA_20])
data_SCI_AD_ALPHA_10= pd.concat([data_SCI_ALPHA_10,data_AD_ALPHA_10])
data_SCI_AD_BETA_100= pd.concat([data_SCI_BETA_100,data_AD_BETA_100])
data_SCI_AD_BETA_70= pd.concat([data_SCI_BETA_70,data_AD_BETA_70])
data_SCI_AD_BETA_50= pd.concat([data_SCI_BETA_50,data_AD_BETA_50])
data_SCI_AD_BETA_30= pd.concat([data_SCI_BETA_30,data_AD_BETA_30])
data_SCI_AD_BETA_20= pd.concat([data_SCI_BETA_20,data_AD_BETA_20])
data_SCI_AD_BETA_10= pd.concat([data_SCI_BETA_10,data_AD_BETA_10])
data_SCI_AD_DELTA_100= pd.concat([data_SCI_DELTA_100,data_AD_DELTA_100])
data_SCI_AD_DELTA_70= pd.concat([data_SCI_DELTA_70,data_AD_DELTA_70])
data_SCI_AD_DELTA_50= pd.concat([data_SCI_DELTA_50,data_AD_DELTA_50])
data_SCI_AD_DELTA_30= pd.concat([data_SCI_DELTA_30,data_AD_DELTA_30])
data_SCI_AD_DELTA_20= pd.concat([data_SCI_DELTA_20,data_AD_DELTA_20])
data_SCI_AD_DELTA_10= pd.concat([data_SCI_DELTA_10,data_AD_DELTA_10])
data_SCI_AD_THETA_100= pd.concat([data_SCI_THETA_100,data_AD_THETA_100])
data_SCI_AD_THETA_70= pd.concat([data_SCI_THETA_70,data_AD_THETA_70])
data_SCI_AD_THETA_50= pd.concat([data_SCI_THETA_50,data_AD_THETA_50])
data_SCI_AD_THETA_30= pd.concat([data_SCI_THETA_30,data_AD_THETA_30])
data_SCI_AD_THETA_20= pd.concat([data_SCI_THETA_20,data_AD_THETA_20])
data_SCI_AD_THETA_10= pd.concat([data_SCI_THETA_10,data_AD_THETA_10])

# %%
#Dataset split
X=data_SCI_AD_ALPHA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_100, X_test_data_SCI_AD_ALPHA_100, y_train_data_SCI_AD_ALPHA_100, y_test_data_SCI_AD_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_70, X_test_data_SCI_AD_ALPHA_70, y_train_data_SCI_AD_ALPHA_70, y_test_data_SCI_AD_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_50, X_test_data_SCI_AD_ALPHA_50, y_train_data_SCI_AD_ALPHA_50, y_test_data_SCI_AD_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_30, X_test_data_SCI_AD_ALPHA_30, y_train_data_SCI_AD_ALPHA_30, y_test_data_SCI_AD_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_20, X_test_data_SCI_AD_ALPHA_20, y_train_data_SCI_AD_ALPHA_20, y_test_data_SCI_AD_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_10, X_test_data_SCI_AD_ALPHA_10, y_train_data_SCI_AD_ALPHA_10, y_test_data_SCI_AD_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_100, X_test_data_SCI_AD_BETA_100, y_train_data_SCI_AD_BETA_100, y_test_data_SCI_AD_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_70, X_test_data_SCI_AD_BETA_70, y_train_data_SCI_AD_BETA_70, y_test_data_SCI_AD_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_50, X_test_data_SCI_AD_BETA_50, y_train_data_SCI_AD_BETA_50, y_test_data_SCI_AD_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_30, X_test_data_SCI_AD_BETA_30, y_train_data_SCI_AD_BETA_30, y_test_data_SCI_AD_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_20, X_test_data_SCI_AD_BETA_20, y_train_data_SCI_AD_BETA_20, y_test_data_SCI_AD_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_10, X_test_data_SCI_AD_BETA_10, y_train_data_SCI_AD_BETA_10, y_test_data_SCI_AD_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_SCI_AD_DELTA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_100, X_test_data_SCI_AD_DELTA_100, y_train_data_SCI_AD_DELTA_100, y_test_data_SCI_AD_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_70, X_test_data_SCI_AD_DELTA_70, y_train_data_SCI_AD_DELTA_70, y_test_data_SCI_AD_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_50, X_test_data_SCI_AD_DELTA_50, y_train_data_SCI_AD_DELTA_50, y_test_data_SCI_AD_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_30, X_test_data_SCI_AD_DELTA_30, y_train_data_SCI_AD_DELTA_30, y_test_data_SCI_AD_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_20, X_test_data_SCI_AD_DELTA_20, y_train_data_SCI_AD_DELTA_20, y_test_data_SCI_AD_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_10, X_test_data_SCI_AD_DELTA_10, y_train_data_SCI_AD_DELTA_10, y_test_data_SCI_AD_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_100, X_test_data_SCI_AD_THETA_100, y_train_data_SCI_AD_THETA_100, y_test_data_SCI_AD_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_70, X_test_data_SCI_AD_THETA_70, y_train_data_SCI_AD_THETA_70, y_test_data_SCI_AD_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_50, X_test_data_SCI_AD_THETA_50, y_train_data_SCI_AD_THETA_50, y_test_data_SCI_AD_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_30, X_test_data_SCI_AD_THETA_30, y_train_data_SCI_AD_THETA_30, y_test_data_SCI_AD_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_20, X_test_data_SCI_AD_THETA_20, y_train_data_SCI_AD_THETA_20, y_test_data_SCI_AD_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_10, X_test_data_SCI_AD_THETA_10, y_train_data_SCI_AD_THETA_10, y_test_data_SCI_AD_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Sélaction 1 : AD vs MCI
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_ALPHA_100, y_train_data_AD_MCI_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_ALPHA_70, y_train_data_AD_MCI_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_ALPHA_50, y_train_data_AD_MCI_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_ALPHA_30, y_train_data_AD_MCI_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_ALPHA_20, y_train_data_AD_MCI_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_ALPHA_10, y_train_data_AD_MCI_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_BETA_100, y_train_data_AD_MCI_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_BETA_70, y_train_data_AD_MCI_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_BETA_50, y_train_data_AD_MCI_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_BETA_30, y_train_data_AD_MCI_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_BETA_20, y_train_data_AD_MCI_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_BETA_10, y_train_data_AD_MCI_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_DELTA_100, y_train_data_AD_MCI_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_DELTA_70, y_train_data_AD_MCI_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_DELTA_50, y_train_data_AD_MCI_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_DELTA_30, y_train_data_AD_MCI_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_DELTA_20, y_train_data_AD_MCI_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_DELTA_10, y_train_data_AD_MCI_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_THETA_100, y_train_data_AD_MCI_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_AD_MCI_THETA_70, y_train_data_AD_MCI_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_50, y_train_data_AD_MCI_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_30, y_train_data_AD_MCI_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_20, y_train_data_AD_MCI_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_10, y_train_data_AD_MCI_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_AD_MCI = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 ad vs mci
dataset_AD_MCI_train= pd.concat([X_train_data_AD_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_AD_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_AD_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_AD_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_AD_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_AD_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_AD_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_AD_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_AD_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_AD_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_AD_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_AD_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_AD_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_AD_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_AD_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_AD_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_AD_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_AD_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_AD_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_AD_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_AD_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_AD_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_AD_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_AD_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_AD_MCI_test= pd.concat([X_test_data_AD_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_AD_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_AD_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_AD_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_AD_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_AD_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_AD_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_AD_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_AD_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_AD_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_AD_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_AD_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_AD_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_AD_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_AD_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_AD_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_AD_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_AD_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_AD_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_AD_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_AD_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_AD_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_AD_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_AD_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_AD_MCI_train.columns = data_col_names_AD_MCI
dataset_AD_MCI_test.columns = data_col_names_AD_MCI

# %%
# Sélaction 1 : SCI vs MCI
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_ALPHA_100, y_train_data_SCI_MCI_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_ALPHA_70, y_train_data_SCI_MCI_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_ALPHA_50, y_train_data_SCI_MCI_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_ALPHA_30, y_train_data_SCI_MCI_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_ALPHA_20, y_train_data_SCI_MCI_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_ALPHA_10, y_train_data_SCI_MCI_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_BETA_100, y_train_data_SCI_MCI_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_BETA_70, y_train_data_SCI_MCI_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_50, y_train_data_SCI_MCI_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_BETA_30, y_train_data_SCI_MCI_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_BETA_20, y_train_data_SCI_MCI_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_BETA_10, y_train_data_SCI_MCI_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_DELTA_100, y_train_data_SCI_MCI_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_DELTA_70, y_train_data_SCI_MCI_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_DELTA_50, y_train_data_SCI_MCI_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_DELTA_30, y_train_data_SCI_MCI_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_DELTA_20, y_train_data_SCI_MCI_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_DELTA_10, y_train_data_SCI_MCI_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_THETA_100, y_train_data_SCI_MCI_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(X_train_data_SCI_MCI_THETA_70, y_train_data_SCI_MCI_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_50, y_train_data_SCI_MCI_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_30, y_train_data_SCI_MCI_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_20, y_train_data_SCI_MCI_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_10, y_train_data_SCI_MCI_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_SCI_MCI = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 SCI vs mci
dataset_SCI_MCI_train= pd.concat([X_train_data_SCI_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_SCI_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_SCI_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_SCI_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_SCI_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_SCI_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_SCI_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_SCI_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_SCI_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_SCI_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_SCI_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_SCI_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_SCI_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_SCI_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_SCI_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_SCI_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_SCI_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_SCI_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_SCI_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_SCI_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_SCI_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_SCI_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_SCI_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_SCI_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_SCI_MCI_test= pd.concat([X_test_data_SCI_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_SCI_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_SCI_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_SCI_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_SCI_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_SCI_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_SCI_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_SCI_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_SCI_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_SCI_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_SCI_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_SCI_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_SCI_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_SCI_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_SCI_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_SCI_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_SCI_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_SCI_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_SCI_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_SCI_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_SCI_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_SCI_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_SCI_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_SCI_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_SCI_MCI_train.columns = data_col_names_SCI_MCI
dataset_SCI_MCI_test.columns = data_col_names_SCI_MCI

# %%
# Sélaction 1 : SCI vs AD
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_100, y_train_data_SCI_AD_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_70, y_train_data_SCI_AD_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_50, y_train_data_SCI_AD_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_30, y_train_data_SCI_AD_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_20, y_train_data_SCI_AD_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_10, y_train_data_SCI_AD_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_100, y_train_data_SCI_AD_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_70, y_train_data_SCI_AD_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_50, y_train_data_SCI_AD_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_30, y_train_data_SCI_AD_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_20, y_train_data_SCI_AD_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_10, y_train_data_SCI_AD_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_100, y_train_data_SCI_AD_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_70, y_train_data_SCI_AD_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_50, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_30, y_train_data_SCI_AD_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_20, y_train_data_SCI_AD_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_10, y_train_data_SCI_AD_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_100, y_train_data_SCI_AD_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_70, y_train_data_SCI_AD_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_50, y_train_data_SCI_AD_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_30, y_train_data_SCI_AD_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_20, y_train_data_SCI_AD_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_10, y_train_data_SCI_AD_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_SCI_AD = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 SCI vs AD
dataset_SCI_AD_train= pd.concat([X_train_data_SCI_AD_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_SCI_AD_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_SCI_AD_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_SCI_AD_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_SCI_AD_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_SCI_AD_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_SCI_AD_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_SCI_AD_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_SCI_AD_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_SCI_AD_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_SCI_AD_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_SCI_AD_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_SCI_AD_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_SCI_AD_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_SCI_AD_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_SCI_AD_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_SCI_AD_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_SCI_AD_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_SCI_AD_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_SCI_AD_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_SCI_AD_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_SCI_AD_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_SCI_AD_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_SCI_AD_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_SCI_AD_test= pd.concat([X_test_data_SCI_AD_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_SCI_AD_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_SCI_AD_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_SCI_AD_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_SCI_AD_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_SCI_AD_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_SCI_AD_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_SCI_AD_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_SCI_AD_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_SCI_AD_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_SCI_AD_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_SCI_AD_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_SCI_AD_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_SCI_AD_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_SCI_AD_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_SCI_AD_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_SCI_AD_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_SCI_AD_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_SCI_AD_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_SCI_AD_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_SCI_AD_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_SCI_AD_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_SCI_AD_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_SCI_AD_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_SCI_AD_train.columns = data_col_names_SCI_AD
dataset_SCI_AD_test.columns = data_col_names_SCI_AD

# %% [raw]
# #Seconde selesction
# #sondes
# sonde1 = np.random.rand(dataset_AD_MCI_train.shape[0])
# sonde2 = np.random.rand(dataset_SCI_MCI_train.shape[0])
# sonde3 = np.random.rand(dataset_SCI_AD_train.shape[0])

# %% [raw]
# dataset_AD_MCI_train['Sonde']= sonde1
# dataset_SCI_MCI_train['Sonde']= sonde2
# dataset_SCI_AD_train['Sonde']= sonde3

# %%
#fonction de selection sonde
def selector (importance, variables, nb):
    t=[]
    for i in range(nb):
        t.append(variables[importance[i]])
    return t

# %%
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(dataset_AD_MCI_train, y_train_data_AD_MCI_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
print(indices)
t=selector(indices,data_col_names_AD_MCI,5)
final_train_dataset_AD_MCI_nb_co = dataset_AD_MCI_train[t]
final_test_dataset_AD_MCI_nb_co = dataset_AD_MCI_test[t]
final_y_train= y_train_data_AD_MCI_DELTA_100
final_y_test= y_test_data_AD_MCI_DELTA_100
# Out:
# [14 19 11  1  2 15 16  9 13 22 21 23  3  8  7 20 10 17  5  4 12  6 18  0]

# %%
model = ExtraTreesClassifier(n_estimators=20)
model.fit(dataset_SCI_MCI_train, y_train_data_SCI_MCI_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_SCI_MCI,5)
final_train_dataset_SCI_MCI_nb_co = dataset_SCI_MCI_train[t]
final_test_dataset_SCI_MCI_nb_co = dataset_SCI_MCI_test[t]
final_y_train= y_train_data_SCI_MCI_DELTA_100
final_y_test= y_test_data_SCI_MCI_DELTA_100

# %%
model = ExtraTreesClassifier(n_estimators=20)
model.fit(dataset_SCI_AD_train, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_SCI_AD,5)
final_train_dataset_SCI_AD_nb_co = dataset_SCI_AD_train[t]
final_test_dataset_SCI_AD_nb_co = dataset_SCI_AD_test[t]
final_y_train= y_train_data_SCI_AD_DELTA_100
final_y_test= y_test_data_SCI_AD_DELTA_100

# %%
matrices_AD = {}
for var in Var:
    matrice=[]
    for i in range (len(x_AD)):
        t = moyenne(x_AD[i][var])
        matrice.append(t)
    matrices_AD[var]= matrice
    
matrices_MCI = {}
for var in Var:
    matrice=[]
    for i in range (len(x_MCI)):
        t = moyenne(x_MCI[i][var])
        matrice.append(t)
    matrices_MCI[var]= matrice
    

matrices_SCI = {}
for var in Var:
    matrice=[]
    for i in range (len(x_SCI)):
        t = moyenne(x_SCI[i][var])
        matrice.append(t)
    matrices_SCI[var]= matrice

# %%
data_AD_ALPHA_100= dataframe_creator(matrices_AD['ALPHA_100'],Elec)
data_AD_ALPHA_70= dataframe_creator(matrices_AD['ALPHA_70'],Elec)
data_AD_ALPHA_50= dataframe_creator(matrices_AD['ALPHA_50'],Elec)
data_AD_ALPHA_30= dataframe_creator(matrices_AD['ALPHA_30'],Elec)
data_AD_ALPHA_20= dataframe_creator(matrices_AD['ALPHA_20'],Elec)
data_AD_ALPHA_10= dataframe_creator(matrices_AD['ALPHA_10'],Elec)
data_AD_BETA_100= dataframe_creator(matrices_AD['BETA_100'],Elec)
data_AD_BETA_70= dataframe_creator(matrices_AD['BETA_70'],Elec)
data_AD_BETA_50= dataframe_creator(matrices_AD['BETA_50'],Elec)
data_AD_BETA_30= dataframe_creator(matrices_AD['BETA_30'],Elec)
data_AD_BETA_20= dataframe_creator(matrices_AD['BETA_20'],Elec)
data_AD_BETA_10= dataframe_creator(matrices_AD['BETA_10'],Elec)
data_AD_DELTA_100= dataframe_creator(matrices_AD['DELTA_100'],Elec)
data_AD_DELTA_70= dataframe_creator(matrices_AD['DELTA_70'],Elec)
data_AD_DELTA_50= dataframe_creator(matrices_AD['DELTA_50'],Elec)
data_AD_DELTA_30= dataframe_creator(matrices_AD['DELTA_30'],Elec)
data_AD_DELTA_20= dataframe_creator(matrices_AD['DELTA_20'],Elec)
data_AD_DELTA_10= dataframe_creator(matrices_AD['DELTA_10'],Elec)
data_AD_THETA_100= dataframe_creator(matrices_AD['THETA_100'],Elec)
data_AD_THETA_70= dataframe_creator(matrices_AD['THETA_70'],Elec)
data_AD_THETA_50= dataframe_creator(matrices_AD['THETA_50'],Elec)
data_AD_THETA_30= dataframe_creator(matrices_AD['THETA_30'],Elec)
data_AD_THETA_20= dataframe_creator(matrices_AD['THETA_20'],Elec)
data_AD_THETA_10= dataframe_creator(matrices_AD['THETA_10'],Elec)

# %%
data_MCI_ALPHA_100= dataframe_creator(matrices_MCI['ALPHA_100'],Elec)
data_MCI_ALPHA_70= dataframe_creator(matrices_MCI['ALPHA_70'],Elec)
data_MCI_ALPHA_50= dataframe_creator(matrices_MCI['ALPHA_50'],Elec)
data_MCI_ALPHA_30= dataframe_creator(matrices_MCI['ALPHA_30'],Elec)
data_MCI_ALPHA_20= dataframe_creator(matrices_MCI['ALPHA_20'],Elec)
data_MCI_ALPHA_10= dataframe_creator(matrices_MCI['ALPHA_10'],Elec)
data_MCI_BETA_100= dataframe_creator(matrices_MCI['BETA_100'],Elec)
data_MCI_BETA_70= dataframe_creator(matrices_MCI['BETA_70'],Elec)
data_MCI_BETA_50= dataframe_creator(matrices_MCI['BETA_50'],Elec)
data_MCI_BETA_30= dataframe_creator(matrices_MCI['BETA_30'],Elec)
data_MCI_BETA_20= dataframe_creator(matrices_MCI['BETA_20'],Elec)
data_MCI_BETA_10= dataframe_creator(matrices_MCI['BETA_10'],Elec)
data_MCI_DELTA_100= dataframe_creator(matrices_MCI['DELTA_100'],Elec)
data_MCI_DELTA_70= dataframe_creator(matrices_MCI['DELTA_70'],Elec)
data_MCI_DELTA_50= dataframe_creator(matrices_MCI['DELTA_50'],Elec)
data_MCI_DELTA_30= dataframe_creator(matrices_MCI['DELTA_30'],Elec)
data_MCI_DELTA_20= dataframe_creator(matrices_MCI['DELTA_20'],Elec)
data_MCI_DELTA_10= dataframe_creator(matrices_MCI['DELTA_10'],Elec)
data_MCI_THETA_100= dataframe_creator(matrices_MCI['THETA_100'],Elec)
data_MCI_THETA_70= dataframe_creator(matrices_MCI['THETA_70'],Elec)
data_MCI_THETA_50= dataframe_creator(matrices_MCI['THETA_50'],Elec)
data_MCI_THETA_30= dataframe_creator(matrices_MCI['THETA_30'],Elec)
data_MCI_THETA_20= dataframe_creator(matrices_MCI['THETA_20'],Elec)
data_MCI_THETA_10= dataframe_creator(matrices_MCI['THETA_10'],Elec)

# %%
data_SCI_ALPHA_100= dataframe_creator(matrices_SCI['ALPHA_100'],Elec)
data_SCI_ALPHA_70= dataframe_creator(matrices_SCI['ALPHA_70'],Elec)
data_SCI_ALPHA_50= dataframe_creator(matrices_SCI['ALPHA_50'],Elec)
data_SCI_ALPHA_30= dataframe_creator(matrices_SCI['ALPHA_30'],Elec)
data_SCI_ALPHA_20= dataframe_creator(matrices_SCI['ALPHA_20'],Elec)
data_SCI_ALPHA_10= dataframe_creator(matrices_SCI['ALPHA_10'],Elec)
data_SCI_BETA_100= dataframe_creator(matrices_SCI['BETA_100'],Elec)
data_SCI_BETA_70= dataframe_creator(matrices_SCI['BETA_70'],Elec)
data_SCI_BETA_50= dataframe_creator(matrices_SCI['BETA_50'],Elec)
data_SCI_BETA_30= dataframe_creator(matrices_SCI['BETA_30'],Elec)
data_SCI_BETA_20= dataframe_creator(matrices_SCI['BETA_20'],Elec)
data_SCI_BETA_10= dataframe_creator(matrices_SCI['BETA_10'],Elec)
data_SCI_DELTA_100= dataframe_creator(matrices_SCI['DELTA_100'],Elec)
data_SCI_DELTA_70= dataframe_creator(matrices_SCI['DELTA_70'],Elec)
data_SCI_DELTA_50= dataframe_creator(matrices_SCI['DELTA_50'],Elec)
data_SCI_DELTA_30= dataframe_creator(matrices_SCI['DELTA_30'],Elec)
data_SCI_DELTA_20= dataframe_creator(matrices_SCI['DELTA_20'],Elec)
data_SCI_DELTA_10= dataframe_creator(matrices_SCI['DELTA_10'],Elec)
data_SCI_THETA_100= dataframe_creator(matrices_SCI['THETA_100'],Elec)
data_SCI_THETA_70= dataframe_creator(matrices_SCI['THETA_70'],Elec)
data_SCI_THETA_50= dataframe_creator(matrices_SCI['THETA_50'],Elec)
data_SCI_THETA_30= dataframe_creator(matrices_SCI['THETA_30'],Elec)
data_SCI_THETA_20= dataframe_creator(matrices_SCI['THETA_20'],Elec)
data_SCI_THETA_10= dataframe_creator(matrices_SCI['THETA_10'],Elec)

# %%
#datasets AD vs MCI
data_AD_MCI_ALPHA_100= pd.concat([data_AD_ALPHA_100,data_MCI_ALPHA_100])
data_AD_MCI_ALPHA_70= pd.concat([data_AD_ALPHA_70,data_MCI_ALPHA_70])
data_AD_MCI_ALPHA_50= pd.concat([data_AD_ALPHA_50,data_MCI_ALPHA_50])
data_AD_MCI_ALPHA_30= pd.concat([data_AD_ALPHA_30,data_MCI_ALPHA_30])
data_AD_MCI_ALPHA_20= pd.concat([data_AD_ALPHA_20,data_MCI_ALPHA_20])
data_AD_MCI_ALPHA_10= pd.concat([data_AD_ALPHA_10,data_MCI_ALPHA_10])
data_AD_MCI_BETA_100= pd.concat([data_AD_BETA_100,data_MCI_BETA_100])
data_AD_MCI_BETA_70= pd.concat([data_AD_BETA_70,data_MCI_BETA_70])
data_AD_MCI_BETA_50= pd.concat([data_AD_BETA_50,data_MCI_BETA_50])
data_AD_MCI_BETA_30= pd.concat([data_AD_BETA_30,data_MCI_BETA_30])
data_AD_MCI_BETA_20= pd.concat([data_AD_BETA_20,data_MCI_BETA_20])
data_AD_MCI_BETA_10= pd.concat([data_AD_BETA_10,data_MCI_BETA_10])
data_AD_MCI_DELTA_100= pd.concat([data_AD_DELTA_100,data_MCI_DELTA_100])
data_AD_MCI_DELTA_70= pd.concat([data_AD_DELTA_70,data_MCI_DELTA_70])
data_AD_MCI_DELTA_50= pd.concat([data_AD_DELTA_50,data_MCI_DELTA_50])
data_AD_MCI_DELTA_30= pd.concat([data_AD_DELTA_30,data_MCI_DELTA_30])
data_AD_MCI_DELTA_20= pd.concat([data_AD_DELTA_20,data_MCI_DELTA_20])
data_AD_MCI_DELTA_10= pd.concat([data_AD_DELTA_10,data_MCI_DELTA_10])
data_AD_MCI_THETA_100= pd.concat([data_AD_THETA_100,data_MCI_THETA_100])
data_AD_MCI_THETA_70= pd.concat([data_AD_THETA_70,data_MCI_THETA_70])
data_AD_MCI_THETA_50= pd.concat([data_AD_THETA_50,data_MCI_THETA_50])
data_AD_MCI_THETA_30= pd.concat([data_AD_THETA_30,data_MCI_THETA_30])
data_AD_MCI_THETA_20= pd.concat([data_AD_THETA_20,data_MCI_THETA_20])
data_AD_MCI_THETA_10= pd.concat([data_AD_THETA_10,data_MCI_THETA_10])

# %%
#Dataset split
X=data_AD_MCI_ALPHA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_100, X_test_data_AD_MCI_ALPHA_100, y_train_data_AD_MCI_ALPHA_100, y_test_data_AD_MCI_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_70, X_test_data_AD_MCI_ALPHA_70, y_train_data_AD_MCI_ALPHA_70, y_test_data_AD_MCI_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_50, X_test_data_AD_MCI_ALPHA_50, y_train_data_AD_MCI_ALPHA_50, y_test_data_AD_MCI_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_30, X_test_data_AD_MCI_ALPHA_30, y_train_data_AD_MCI_ALPHA_30, y_test_data_AD_MCI_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_20, X_test_data_AD_MCI_ALPHA_20, y_train_data_AD_MCI_ALPHA_20, y_test_data_AD_MCI_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_10, X_test_data_AD_MCI_ALPHA_10, y_train_data_AD_MCI_ALPHA_10, y_test_data_AD_MCI_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_100, X_test_data_AD_MCI_BETA_100, y_train_data_AD_MCI_BETA_100, y_test_data_AD_MCI_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_70, X_test_data_AD_MCI_BETA_70, y_train_data_AD_MCI_BETA_70, y_test_data_AD_MCI_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_50, X_test_data_AD_MCI_BETA_50, y_train_data_AD_MCI_BETA_50, y_test_data_AD_MCI_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_30, X_test_data_AD_MCI_BETA_30, y_train_data_AD_MCI_BETA_30, y_test_data_AD_MCI_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_20, X_test_data_AD_MCI_BETA_20, y_train_data_AD_MCI_BETA_20, y_test_data_AD_MCI_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_10, X_test_data_AD_MCI_BETA_10, y_train_data_AD_MCI_BETA_10, y_test_data_AD_MCI_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_AD_MCI_DELTA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_100, X_test_data_AD_MCI_DELTA_100, y_train_data_AD_MCI_DELTA_100, y_test_data_AD_MCI_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_70, X_test_data_AD_MCI_DELTA_70, y_train_data_AD_MCI_DELTA_70, y_test_data_AD_MCI_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_50, X_test_data_AD_MCI_DELTA_50, y_train_data_AD_MCI_DELTA_50, y_test_data_AD_MCI_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_30, X_test_data_AD_MCI_DELTA_30, y_train_data_AD_MCI_DELTA_30, y_test_data_AD_MCI_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_20, X_test_data_AD_MCI_DELTA_20, y_train_data_AD_MCI_DELTA_20, y_test_data_AD_MCI_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_10, X_test_data_AD_MCI_DELTA_10, y_train_data_AD_MCI_DELTA_10, y_test_data_AD_MCI_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_100, X_test_data_AD_MCI_THETA_100, y_train_data_AD_MCI_THETA_100, y_test_data_AD_MCI_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_70, X_test_data_AD_MCI_THETA_70, y_train_data_AD_MCI_THETA_70, y_test_data_AD_MCI_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_50, X_test_data_AD_MCI_THETA_50, y_train_data_AD_MCI_THETA_50, y_test_data_AD_MCI_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_30, X_test_data_AD_MCI_THETA_30, y_train_data_AD_MCI_THETA_30, y_test_data_AD_MCI_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_20, X_test_data_AD_MCI_THETA_20, y_train_data_AD_MCI_THETA_20, y_test_data_AD_MCI_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_10, X_test_data_AD_MCI_THETA_10, y_train_data_AD_MCI_THETA_10, y_test_data_AD_MCI_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
#datasets SCI vs MCI
data_SCI_MCI_ALPHA_100= pd.concat([data_SCI_ALPHA_100,data_MCI_ALPHA_100])
data_SCI_MCI_ALPHA_70= pd.concat([data_SCI_ALPHA_70,data_MCI_ALPHA_70])
data_SCI_MCI_ALPHA_50= pd.concat([data_SCI_ALPHA_50,data_MCI_ALPHA_50])
data_SCI_MCI_ALPHA_30= pd.concat([data_SCI_ALPHA_30,data_MCI_ALPHA_30])
data_SCI_MCI_ALPHA_20= pd.concat([data_SCI_ALPHA_20,data_MCI_ALPHA_20])
data_SCI_MCI_ALPHA_10= pd.concat([data_SCI_ALPHA_10,data_MCI_ALPHA_10])
data_SCI_MCI_BETA_100= pd.concat([data_SCI_BETA_100,data_MCI_BETA_100])
data_SCI_MCI_BETA_70= pd.concat([data_SCI_BETA_70,data_MCI_BETA_70])
data_SCI_MCI_BETA_50= pd.concat([data_SCI_BETA_50,data_MCI_BETA_50])
data_SCI_MCI_BETA_30= pd.concat([data_SCI_BETA_30,data_MCI_BETA_30])
data_SCI_MCI_BETA_20= pd.concat([data_SCI_BETA_20,data_MCI_BETA_20])
data_SCI_MCI_BETA_10= pd.concat([data_SCI_BETA_10,data_MCI_BETA_10])
data_SCI_MCI_DELTA_100= pd.concat([data_SCI_DELTA_100,data_MCI_DELTA_100])
data_SCI_MCI_DELTA_70= pd.concat([data_SCI_DELTA_70,data_MCI_DELTA_70])
data_SCI_MCI_DELTA_50= pd.concat([data_SCI_DELTA_50,data_MCI_DELTA_50])
data_SCI_MCI_DELTA_30= pd.concat([data_SCI_DELTA_30,data_MCI_DELTA_30])
data_SCI_MCI_DELTA_20= pd.concat([data_SCI_DELTA_20,data_MCI_DELTA_20])
data_SCI_MCI_DELTA_10= pd.concat([data_SCI_DELTA_10,data_MCI_DELTA_10])
data_SCI_MCI_THETA_100= pd.concat([data_SCI_THETA_100,data_MCI_THETA_100])
data_SCI_MCI_THETA_70= pd.concat([data_SCI_THETA_70,data_MCI_THETA_70])
data_SCI_MCI_THETA_50= pd.concat([data_SCI_THETA_50,data_MCI_THETA_50])
data_SCI_MCI_THETA_30= pd.concat([data_SCI_THETA_30,data_MCI_THETA_30])
data_SCI_MCI_THETA_20= pd.concat([data_SCI_THETA_20,data_MCI_THETA_20])
data_SCI_MCI_THETA_10= pd.concat([data_SCI_THETA_10,data_MCI_THETA_10])

# %%
#Dataset split
X=data_SCI_MCI_ALPHA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_100, X_test_data_SCI_MCI_ALPHA_100, y_train_data_SCI_MCI_ALPHA_100, y_test_data_SCI_MCI_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_70, X_test_data_SCI_MCI_ALPHA_70, y_train_data_SCI_MCI_ALPHA_70, y_test_data_SCI_MCI_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_50, X_test_data_SCI_MCI_ALPHA_50, y_train_data_SCI_MCI_ALPHA_50, y_test_data_SCI_MCI_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_30, X_test_data_SCI_MCI_ALPHA_30, y_train_data_SCI_MCI_ALPHA_30, y_test_data_SCI_MCI_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_20, X_test_data_SCI_MCI_ALPHA_20, y_train_data_SCI_MCI_ALPHA_20, y_test_data_SCI_MCI_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_10, X_test_data_SCI_MCI_ALPHA_10, y_train_data_SCI_MCI_ALPHA_10, y_test_data_SCI_MCI_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_100, X_test_data_SCI_MCI_BETA_100, y_train_data_SCI_MCI_BETA_100, y_test_data_SCI_MCI_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_70, X_test_data_SCI_MCI_BETA_70, y_train_data_SCI_MCI_BETA_70, y_test_data_SCI_MCI_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_50, X_test_data_SCI_MCI_BETA_50, y_train_data_SCI_MCI_BETA_50, y_test_data_SCI_MCI_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_30, X_test_data_SCI_MCI_BETA_30, y_train_data_SCI_MCI_BETA_30, y_test_data_SCI_MCI_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_20, X_test_data_SCI_MCI_BETA_20, y_train_data_SCI_MCI_BETA_20, y_test_data_SCI_MCI_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_10, X_test_data_SCI_MCI_BETA_10, y_train_data_SCI_MCI_BETA_10, y_test_data_SCI_MCI_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_SCI_MCI_DELTA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_100, X_test_data_SCI_MCI_DELTA_100, y_train_data_SCI_MCI_DELTA_100, y_test_data_SCI_MCI_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_70, X_test_data_SCI_MCI_DELTA_70, y_train_data_SCI_MCI_DELTA_70, y_test_data_SCI_MCI_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_50, X_test_data_SCI_MCI_DELTA_50, y_train_data_SCI_MCI_DELTA_50, y_test_data_SCI_MCI_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_30, X_test_data_SCI_MCI_DELTA_30, y_train_data_SCI_MCI_DELTA_30, y_test_data_SCI_MCI_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_20, X_test_data_SCI_MCI_DELTA_20, y_train_data_SCI_MCI_DELTA_20, y_test_data_SCI_MCI_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_10, X_test_data_SCI_MCI_DELTA_10, y_train_data_SCI_MCI_DELTA_10, y_test_data_SCI_MCI_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_100, X_test_data_SCI_MCI_THETA_100, y_train_data_SCI_MCI_THETA_100, y_test_data_SCI_MCI_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_70, X_test_data_SCI_MCI_THETA_70, y_train_data_SCI_MCI_THETA_70, y_test_data_SCI_MCI_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_50, X_test_data_SCI_MCI_THETA_50, y_train_data_SCI_MCI_THETA_50, y_test_data_SCI_MCI_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_30, X_test_data_SCI_MCI_THETA_30, y_train_data_SCI_MCI_THETA_30, y_test_data_SCI_MCI_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_20, X_test_data_SCI_MCI_THETA_20, y_train_data_SCI_MCI_THETA_20, y_test_data_SCI_MCI_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_10, X_test_data_SCI_MCI_THETA_10, y_train_data_SCI_MCI_THETA_10, y_test_data_SCI_MCI_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
#datasets SCI vs AD
data_SCI_AD_ALPHA_100= pd.concat([data_SCI_ALPHA_100,data_AD_ALPHA_100])
data_SCI_AD_ALPHA_70= pd.concat([data_SCI_ALPHA_70,data_AD_ALPHA_70])
data_SCI_AD_ALPHA_50= pd.concat([data_SCI_ALPHA_50,data_AD_ALPHA_50])
data_SCI_AD_ALPHA_30= pd.concat([data_SCI_ALPHA_30,data_AD_ALPHA_30])
data_SCI_AD_ALPHA_20= pd.concat([data_SCI_ALPHA_20,data_AD_ALPHA_20])
data_SCI_AD_ALPHA_10= pd.concat([data_SCI_ALPHA_10,data_AD_ALPHA_10])
data_SCI_AD_BETA_100= pd.concat([data_SCI_BETA_100,data_AD_BETA_100])
data_SCI_AD_BETA_70= pd.concat([data_SCI_BETA_70,data_AD_BETA_70])
data_SCI_AD_BETA_50= pd.concat([data_SCI_BETA_50,data_AD_BETA_50])
data_SCI_AD_BETA_30= pd.concat([data_SCI_BETA_30,data_AD_BETA_30])
data_SCI_AD_BETA_20= pd.concat([data_SCI_BETA_20,data_AD_BETA_20])
data_SCI_AD_BETA_10= pd.concat([data_SCI_BETA_10,data_AD_BETA_10])
data_SCI_AD_DELTA_100= pd.concat([data_SCI_DELTA_100,data_AD_DELTA_100])
data_SCI_AD_DELTA_70= pd.concat([data_SCI_DELTA_70,data_AD_DELTA_70])
data_SCI_AD_DELTA_50= pd.concat([data_SCI_DELTA_50,data_AD_DELTA_50])
data_SCI_AD_DELTA_30= pd.concat([data_SCI_DELTA_30,data_AD_DELTA_30])
data_SCI_AD_DELTA_20= pd.concat([data_SCI_DELTA_20,data_AD_DELTA_20])
data_SCI_AD_DELTA_10= pd.concat([data_SCI_DELTA_10,data_AD_DELTA_10])
data_SCI_AD_THETA_100= pd.concat([data_SCI_THETA_100,data_AD_THETA_100])
data_SCI_AD_THETA_70= pd.concat([data_SCI_THETA_70,data_AD_THETA_70])
data_SCI_AD_THETA_50= pd.concat([data_SCI_THETA_50,data_AD_THETA_50])
data_SCI_AD_THETA_30= pd.concat([data_SCI_THETA_30,data_AD_THETA_30])
data_SCI_AD_THETA_20= pd.concat([data_SCI_THETA_20,data_AD_THETA_20])
data_SCI_AD_THETA_10= pd.concat([data_SCI_THETA_10,data_AD_THETA_10])

# %%
#Dataset split
X=data_SCI_AD_ALPHA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_100, X_test_data_SCI_AD_ALPHA_100, y_train_data_SCI_AD_ALPHA_100, y_test_data_SCI_AD_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_70, X_test_data_SCI_AD_ALPHA_70, y_train_data_SCI_AD_ALPHA_70, y_test_data_SCI_AD_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_50, X_test_data_SCI_AD_ALPHA_50, y_train_data_SCI_AD_ALPHA_50, y_test_data_SCI_AD_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_30, X_test_data_SCI_AD_ALPHA_30, y_train_data_SCI_AD_ALPHA_30, y_test_data_SCI_AD_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_20, X_test_data_SCI_AD_ALPHA_20, y_train_data_SCI_AD_ALPHA_20, y_test_data_SCI_AD_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_10, X_test_data_SCI_AD_ALPHA_10, y_train_data_SCI_AD_ALPHA_10, y_test_data_SCI_AD_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_100, X_test_data_SCI_AD_BETA_100, y_train_data_SCI_AD_BETA_100, y_test_data_SCI_AD_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_70, X_test_data_SCI_AD_BETA_70, y_train_data_SCI_AD_BETA_70, y_test_data_SCI_AD_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_50, X_test_data_SCI_AD_BETA_50, y_train_data_SCI_AD_BETA_50, y_test_data_SCI_AD_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_30, X_test_data_SCI_AD_BETA_30, y_train_data_SCI_AD_BETA_30, y_test_data_SCI_AD_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_20, X_test_data_SCI_AD_BETA_20, y_train_data_SCI_AD_BETA_20, y_test_data_SCI_AD_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_10, X_test_data_SCI_AD_BETA_10, y_train_data_SCI_AD_BETA_10, y_test_data_SCI_AD_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_SCI_AD_DELTA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_100, X_test_data_SCI_AD_DELTA_100, y_train_data_SCI_AD_DELTA_100, y_test_data_SCI_AD_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_70, X_test_data_SCI_AD_DELTA_70, y_train_data_SCI_AD_DELTA_70, y_test_data_SCI_AD_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_50, X_test_data_SCI_AD_DELTA_50, y_train_data_SCI_AD_DELTA_50, y_test_data_SCI_AD_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_30, X_test_data_SCI_AD_DELTA_30, y_train_data_SCI_AD_DELTA_30, y_test_data_SCI_AD_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_20, X_test_data_SCI_AD_DELTA_20, y_train_data_SCI_AD_DELTA_20, y_test_data_SCI_AD_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_10, X_test_data_SCI_AD_DELTA_10, y_train_data_SCI_AD_DELTA_10, y_test_data_SCI_AD_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_100, X_test_data_SCI_AD_THETA_100, y_train_data_SCI_AD_THETA_100, y_test_data_SCI_AD_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_70, X_test_data_SCI_AD_THETA_70, y_train_data_SCI_AD_THETA_70, y_test_data_SCI_AD_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_50, X_test_data_SCI_AD_THETA_50, y_train_data_SCI_AD_THETA_50, y_test_data_SCI_AD_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_30, X_test_data_SCI_AD_THETA_30, y_train_data_SCI_AD_THETA_30, y_test_data_SCI_AD_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_20, X_test_data_SCI_AD_THETA_20, y_train_data_SCI_AD_THETA_20, y_test_data_SCI_AD_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_10, X_test_data_SCI_AD_THETA_10, y_train_data_SCI_AD_THETA_10, y_test_data_SCI_AD_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Sélaction 1 : AD vs MCI
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_100, y_train_data_AD_MCI_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_70, y_train_data_AD_MCI_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_50, y_train_data_AD_MCI_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_30, y_train_data_AD_MCI_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_20, y_train_data_AD_MCI_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_10, y_train_data_AD_MCI_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_100, y_train_data_AD_MCI_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_70, y_train_data_AD_MCI_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_50, y_train_data_AD_MCI_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_30, y_train_data_AD_MCI_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_20, y_train_data_AD_MCI_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_10, y_train_data_AD_MCI_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_100, y_train_data_AD_MCI_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_70, y_train_data_AD_MCI_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_50, y_train_data_AD_MCI_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_30, y_train_data_AD_MCI_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_20, y_train_data_AD_MCI_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_10, y_train_data_AD_MCI_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_100, y_train_data_AD_MCI_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_70, y_train_data_AD_MCI_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_50, y_train_data_AD_MCI_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_30, y_train_data_AD_MCI_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_20, y_train_data_AD_MCI_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_10, y_train_data_AD_MCI_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_AD_MCI = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 ad vs mci
dataset_AD_MCI_train= pd.concat([X_train_data_AD_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_AD_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_AD_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_AD_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_AD_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_AD_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_AD_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_AD_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_AD_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_AD_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_AD_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_AD_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_AD_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_AD_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_AD_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_AD_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_AD_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_AD_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_AD_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_AD_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_AD_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_AD_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_AD_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_AD_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_AD_MCI_test= pd.concat([X_test_data_AD_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_AD_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_AD_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_AD_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_AD_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_AD_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_AD_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_AD_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_AD_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_AD_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_AD_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_AD_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_AD_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_AD_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_AD_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_AD_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_AD_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_AD_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_AD_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_AD_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_AD_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_AD_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_AD_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_AD_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_AD_MCI_train.columns = data_col_names_AD_MCI
dataset_AD_MCI_test.columns = data_col_names_AD_MCI

# %%
# Sélaction 1 : SCI vs MCI
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_100, y_train_data_SCI_MCI_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_70, y_train_data_SCI_MCI_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_50, y_train_data_SCI_MCI_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_30, y_train_data_SCI_MCI_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_20, y_train_data_SCI_MCI_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_10, y_train_data_SCI_MCI_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_100, y_train_data_SCI_MCI_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_70, y_train_data_SCI_MCI_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_50, y_train_data_SCI_MCI_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_30, y_train_data_SCI_MCI_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_20, y_train_data_SCI_MCI_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_10, y_train_data_SCI_MCI_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_100, y_train_data_SCI_MCI_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_70, y_train_data_SCI_MCI_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_50, y_train_data_SCI_MCI_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_30, y_train_data_SCI_MCI_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_20, y_train_data_SCI_MCI_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_10, y_train_data_SCI_MCI_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_100, y_train_data_SCI_MCI_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_70, y_train_data_SCI_MCI_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_50, y_train_data_SCI_MCI_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_30, y_train_data_SCI_MCI_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_20, y_train_data_SCI_MCI_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_10, y_train_data_SCI_MCI_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_SCI_MCI = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 SCI vs mci
dataset_SCI_MCI_train= pd.concat([X_train_data_SCI_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_SCI_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_SCI_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_SCI_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_SCI_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_SCI_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_SCI_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_SCI_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_SCI_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_SCI_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_SCI_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_SCI_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_SCI_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_SCI_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_SCI_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_SCI_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_SCI_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_SCI_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_SCI_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_SCI_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_SCI_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_SCI_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_SCI_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_SCI_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_SCI_MCI_test= pd.concat([X_test_data_SCI_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_SCI_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_SCI_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_SCI_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_SCI_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_SCI_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_SCI_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_SCI_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_SCI_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_SCI_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_SCI_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_SCI_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_SCI_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_SCI_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_SCI_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_SCI_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_SCI_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_SCI_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_SCI_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_SCI_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_SCI_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_SCI_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_SCI_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_SCI_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_SCI_MCI_train.columns = data_col_names_SCI_MCI
dataset_SCI_MCI_test.columns = data_col_names_SCI_MCI

# %%
# Sélaction 1 : SCI vs AD
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_100, y_train_data_SCI_AD_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_70, y_train_data_SCI_AD_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_50, y_train_data_SCI_AD_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_30, y_train_data_SCI_AD_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_20, y_train_data_SCI_AD_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_10, y_train_data_SCI_AD_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_100, y_train_data_SCI_AD_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_70, y_train_data_SCI_AD_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_50, y_train_data_SCI_AD_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_30, y_train_data_SCI_AD_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_20, y_train_data_SCI_AD_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_10, y_train_data_SCI_AD_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_100, y_train_data_SCI_AD_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_70, y_train_data_SCI_AD_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_50, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_30, y_train_data_SCI_AD_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_20, y_train_data_SCI_AD_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_10, y_train_data_SCI_AD_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_100, y_train_data_SCI_AD_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_70, y_train_data_SCI_AD_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_50, y_train_data_SCI_AD_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_30, y_train_data_SCI_AD_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_20, y_train_data_SCI_AD_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_10, y_train_data_SCI_AD_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_SCI_AD = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 SCI vs AD
dataset_SCI_AD_train= pd.concat([X_train_data_SCI_AD_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_SCI_AD_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_SCI_AD_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_SCI_AD_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_SCI_AD_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_SCI_AD_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_SCI_AD_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_SCI_AD_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_SCI_AD_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_SCI_AD_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_SCI_AD_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_SCI_AD_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_SCI_AD_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_SCI_AD_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_SCI_AD_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_SCI_AD_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_SCI_AD_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_SCI_AD_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_SCI_AD_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_SCI_AD_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_SCI_AD_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_SCI_AD_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_SCI_AD_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_SCI_AD_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_SCI_AD_test= pd.concat([X_test_data_SCI_AD_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_SCI_AD_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_SCI_AD_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_SCI_AD_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_SCI_AD_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_SCI_AD_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_SCI_AD_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_SCI_AD_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_SCI_AD_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_SCI_AD_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_SCI_AD_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_SCI_AD_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_SCI_AD_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_SCI_AD_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_SCI_AD_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_SCI_AD_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_SCI_AD_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_SCI_AD_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_SCI_AD_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_SCI_AD_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_SCI_AD_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_SCI_AD_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_SCI_AD_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_SCI_AD_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_SCI_AD_train.columns = data_col_names_SCI_AD
dataset_SCI_AD_test.columns = data_col_names_SCI_AD

# %% [raw]
# #Seconde selesction
# #sondes
# sonde1 = np.random.rand(dataset_AD_MCI_train.shape[0])
# sonde2 = np.random.rand(dataset_SCI_MCI_train.shape[0])
# sonde3 = np.random.rand(dataset_SCI_AD_train.shape[0])

# %% [raw]
# dataset_AD_MCI_train['Sonde']= sonde1
# dataset_SCI_MCI_train['Sonde']= sonde2
# dataset_SCI_AD_train['Sonde']= sonde3

# %%
#fonction de selection sonde
def selector (importance, variables, nb):
    t=[]
    for i in range(nb):
        t.append(variables[importance[i]])
    return t

# %%
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(dataset_AD_MCI_train, y_train_data_AD_MCI_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_AD_MCI,5)
final_train_dataset_AD_MCI_moy = dataset_AD_MCI_train[t]
final_test_dataset_AD_MCI_moy = dataset_AD_MCI_test[t]
final_y_train= y_train_data_AD_MCI_DELTA_100
final_y_test= y_test_data_AD_MCI_DELTA_100

# %%
model = ExtraTreesClassifier(n_estimators=20)
model.fit(dataset_SCI_MCI_train, y_train_data_SCI_MCI_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_SCI_MCI,5)
final_train_dataset_SCI_MCI_moy = dataset_SCI_MCI_train[t]
final_test_dataset_SCI_MCI_moy = dataset_SCI_MCI_test[t]
final_y_train= y_train_data_SCI_MCI_DELTA_100
final_y_test= y_test_data_SCI_MCI_DELTA_100

# %%
model = ExtraTreesClassifier(n_estimators=20)
model.fit(dataset_SCI_AD_train, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_SCI_AD,5)
final_train_dataset_SCI_AD_moy = dataset_SCI_AD_train[t]
final_test_dataset_SCI_AD_moy = dataset_SCI_AD_test[t]
final_y_train= y_train_data_SCI_AD_DELTA_100
final_y_test= y_test_data_SCI_AD_DELTA_100

# %%
matrices_AD = {}
for var in Var:
    matrice=[]
    for i in range (len(x_AD)):
        t = variance_cdf(x_AD[i][var])
        matrice.append(t)
    matrices_AD[var]= matrice
    
matrices_MCI = {}
for var in Var:
    matrice=[]
    for i in range (len(x_MCI)):
        t = variance_cdf(x_MCI[i][var])
        matrice.append(t)
    matrices_MCI[var]= matrice
    

matrices_SCI = {}
for var in Var:
    matrice=[]
    for i in range (len(x_SCI)):
        t = variance_cdf(x_SCI[i][var])
        matrice.append(t)
    matrices_SCI[var]= matrice

# %%
data_AD_ALPHA_100= dataframe_creator(matrices_AD['ALPHA_100'],Elec)
data_AD_ALPHA_70= dataframe_creator(matrices_AD['ALPHA_70'],Elec)
data_AD_ALPHA_50= dataframe_creator(matrices_AD['ALPHA_50'],Elec)
data_AD_ALPHA_30= dataframe_creator(matrices_AD['ALPHA_30'],Elec)
data_AD_ALPHA_20= dataframe_creator(matrices_AD['ALPHA_20'],Elec)
data_AD_ALPHA_10= dataframe_creator(matrices_AD['ALPHA_10'],Elec)
data_AD_BETA_100= dataframe_creator(matrices_AD['BETA_100'],Elec)
data_AD_BETA_70= dataframe_creator(matrices_AD['BETA_70'],Elec)
data_AD_BETA_50= dataframe_creator(matrices_AD['BETA_50'],Elec)
data_AD_BETA_30= dataframe_creator(matrices_AD['BETA_30'],Elec)
data_AD_BETA_20= dataframe_creator(matrices_AD['BETA_20'],Elec)
data_AD_BETA_10= dataframe_creator(matrices_AD['BETA_10'],Elec)
data_AD_DELTA_100= dataframe_creator(matrices_AD['DELTA_100'],Elec)
data_AD_DELTA_70= dataframe_creator(matrices_AD['DELTA_70'],Elec)
data_AD_DELTA_50= dataframe_creator(matrices_AD['DELTA_50'],Elec)
data_AD_DELTA_30= dataframe_creator(matrices_AD['DELTA_30'],Elec)
data_AD_DELTA_20= dataframe_creator(matrices_AD['DELTA_20'],Elec)
data_AD_DELTA_10= dataframe_creator(matrices_AD['DELTA_10'],Elec)
data_AD_THETA_100= dataframe_creator(matrices_AD['THETA_100'],Elec)
data_AD_THETA_70= dataframe_creator(matrices_AD['THETA_70'],Elec)
data_AD_THETA_50= dataframe_creator(matrices_AD['THETA_50'],Elec)
data_AD_THETA_30= dataframe_creator(matrices_AD['THETA_30'],Elec)
data_AD_THETA_20= dataframe_creator(matrices_AD['THETA_20'],Elec)
data_AD_THETA_10= dataframe_creator(matrices_AD['THETA_10'],Elec)

# %%
data_MCI_ALPHA_100= dataframe_creator(matrices_MCI['ALPHA_100'],Elec)
data_MCI_ALPHA_70= dataframe_creator(matrices_MCI['ALPHA_70'],Elec)
data_MCI_ALPHA_50= dataframe_creator(matrices_MCI['ALPHA_50'],Elec)
data_MCI_ALPHA_30= dataframe_creator(matrices_MCI['ALPHA_30'],Elec)
data_MCI_ALPHA_20= dataframe_creator(matrices_MCI['ALPHA_20'],Elec)
data_MCI_ALPHA_10= dataframe_creator(matrices_MCI['ALPHA_10'],Elec)
data_MCI_BETA_100= dataframe_creator(matrices_MCI['BETA_100'],Elec)
data_MCI_BETA_70= dataframe_creator(matrices_MCI['BETA_70'],Elec)
data_MCI_BETA_50= dataframe_creator(matrices_MCI['BETA_50'],Elec)
data_MCI_BETA_30= dataframe_creator(matrices_MCI['BETA_30'],Elec)
data_MCI_BETA_20= dataframe_creator(matrices_MCI['BETA_20'],Elec)
data_MCI_BETA_10= dataframe_creator(matrices_MCI['BETA_10'],Elec)
data_MCI_DELTA_100= dataframe_creator(matrices_MCI['DELTA_100'],Elec)
data_MCI_DELTA_70= dataframe_creator(matrices_MCI['DELTA_70'],Elec)
data_MCI_DELTA_50= dataframe_creator(matrices_MCI['DELTA_50'],Elec)
data_MCI_DELTA_30= dataframe_creator(matrices_MCI['DELTA_30'],Elec)
data_MCI_DELTA_20= dataframe_creator(matrices_MCI['DELTA_20'],Elec)
data_MCI_DELTA_10= dataframe_creator(matrices_MCI['DELTA_10'],Elec)
data_MCI_THETA_100= dataframe_creator(matrices_MCI['THETA_100'],Elec)
data_MCI_THETA_70= dataframe_creator(matrices_MCI['THETA_70'],Elec)
data_MCI_THETA_50= dataframe_creator(matrices_MCI['THETA_50'],Elec)
data_MCI_THETA_30= dataframe_creator(matrices_MCI['THETA_30'],Elec)
data_MCI_THETA_20= dataframe_creator(matrices_MCI['THETA_20'],Elec)
data_MCI_THETA_10= dataframe_creator(matrices_MCI['THETA_10'],Elec)

# %%
data_SCI_ALPHA_100= dataframe_creator(matrices_SCI['ALPHA_100'],Elec)
data_SCI_ALPHA_70= dataframe_creator(matrices_SCI['ALPHA_70'],Elec)
data_SCI_ALPHA_50= dataframe_creator(matrices_SCI['ALPHA_50'],Elec)
data_SCI_ALPHA_30= dataframe_creator(matrices_SCI['ALPHA_30'],Elec)
data_SCI_ALPHA_20= dataframe_creator(matrices_SCI['ALPHA_20'],Elec)
data_SCI_ALPHA_10= dataframe_creator(matrices_SCI['ALPHA_10'],Elec)
data_SCI_BETA_100= dataframe_creator(matrices_SCI['BETA_100'],Elec)
data_SCI_BETA_70= dataframe_creator(matrices_SCI['BETA_70'],Elec)
data_SCI_BETA_50= dataframe_creator(matrices_SCI['BETA_50'],Elec)
data_SCI_BETA_30= dataframe_creator(matrices_SCI['BETA_30'],Elec)
data_SCI_BETA_20= dataframe_creator(matrices_SCI['BETA_20'],Elec)
data_SCI_BETA_10= dataframe_creator(matrices_SCI['BETA_10'],Elec)
data_SCI_DELTA_100= dataframe_creator(matrices_SCI['DELTA_100'],Elec)
data_SCI_DELTA_70= dataframe_creator(matrices_SCI['DELTA_70'],Elec)
data_SCI_DELTA_50= dataframe_creator(matrices_SCI['DELTA_50'],Elec)
data_SCI_DELTA_30= dataframe_creator(matrices_SCI['DELTA_30'],Elec)
data_SCI_DELTA_20= dataframe_creator(matrices_SCI['DELTA_20'],Elec)
data_SCI_DELTA_10= dataframe_creator(matrices_SCI['DELTA_10'],Elec)
data_SCI_THETA_100= dataframe_creator(matrices_SCI['THETA_100'],Elec)
data_SCI_THETA_70= dataframe_creator(matrices_SCI['THETA_70'],Elec)
data_SCI_THETA_50= dataframe_creator(matrices_SCI['THETA_50'],Elec)
data_SCI_THETA_30= dataframe_creator(matrices_SCI['THETA_30'],Elec)
data_SCI_THETA_20= dataframe_creator(matrices_SCI['THETA_20'],Elec)
data_SCI_THETA_10= dataframe_creator(matrices_SCI['THETA_10'],Elec)

# %%
#datasets AD vs MCI
data_AD_MCI_ALPHA_100= pd.concat([data_AD_ALPHA_100,data_MCI_ALPHA_100])
data_AD_MCI_ALPHA_70= pd.concat([data_AD_ALPHA_70,data_MCI_ALPHA_70])
data_AD_MCI_ALPHA_50= pd.concat([data_AD_ALPHA_50,data_MCI_ALPHA_50])
data_AD_MCI_ALPHA_30= pd.concat([data_AD_ALPHA_30,data_MCI_ALPHA_30])
data_AD_MCI_ALPHA_20= pd.concat([data_AD_ALPHA_20,data_MCI_ALPHA_20])
data_AD_MCI_ALPHA_10= pd.concat([data_AD_ALPHA_10,data_MCI_ALPHA_10])
data_AD_MCI_BETA_100= pd.concat([data_AD_BETA_100,data_MCI_BETA_100])
data_AD_MCI_BETA_70= pd.concat([data_AD_BETA_70,data_MCI_BETA_70])
data_AD_MCI_BETA_50= pd.concat([data_AD_BETA_50,data_MCI_BETA_50])
data_AD_MCI_BETA_30= pd.concat([data_AD_BETA_30,data_MCI_BETA_30])
data_AD_MCI_BETA_20= pd.concat([data_AD_BETA_20,data_MCI_BETA_20])
data_AD_MCI_BETA_10= pd.concat([data_AD_BETA_10,data_MCI_BETA_10])
data_AD_MCI_DELTA_100= pd.concat([data_AD_DELTA_100,data_MCI_DELTA_100])
data_AD_MCI_DELTA_70= pd.concat([data_AD_DELTA_70,data_MCI_DELTA_70])
data_AD_MCI_DELTA_50= pd.concat([data_AD_DELTA_50,data_MCI_DELTA_50])
data_AD_MCI_DELTA_30= pd.concat([data_AD_DELTA_30,data_MCI_DELTA_30])
data_AD_MCI_DELTA_20= pd.concat([data_AD_DELTA_20,data_MCI_DELTA_20])
data_AD_MCI_DELTA_10= pd.concat([data_AD_DELTA_10,data_MCI_DELTA_10])
data_AD_MCI_THETA_100= pd.concat([data_AD_THETA_100,data_MCI_THETA_100])
data_AD_MCI_THETA_70= pd.concat([data_AD_THETA_70,data_MCI_THETA_70])
data_AD_MCI_THETA_50= pd.concat([data_AD_THETA_50,data_MCI_THETA_50])
data_AD_MCI_THETA_30= pd.concat([data_AD_THETA_30,data_MCI_THETA_30])
data_AD_MCI_THETA_20= pd.concat([data_AD_THETA_20,data_MCI_THETA_20])
data_AD_MCI_THETA_10= pd.concat([data_AD_THETA_10,data_MCI_THETA_10])

# %%
#Dataset split
X=data_AD_MCI_ALPHA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_100, X_test_data_AD_MCI_ALPHA_100, y_train_data_AD_MCI_ALPHA_100, y_test_data_AD_MCI_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_70, X_test_data_AD_MCI_ALPHA_70, y_train_data_AD_MCI_ALPHA_70, y_test_data_AD_MCI_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_50, X_test_data_AD_MCI_ALPHA_50, y_train_data_AD_MCI_ALPHA_50, y_test_data_AD_MCI_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_30, X_test_data_AD_MCI_ALPHA_30, y_train_data_AD_MCI_ALPHA_30, y_test_data_AD_MCI_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_20, X_test_data_AD_MCI_ALPHA_20, y_train_data_AD_MCI_ALPHA_20, y_test_data_AD_MCI_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_ALPHA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_ALPHA_10, X_test_data_AD_MCI_ALPHA_10, y_train_data_AD_MCI_ALPHA_10, y_test_data_AD_MCI_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_100, X_test_data_AD_MCI_BETA_100, y_train_data_AD_MCI_BETA_100, y_test_data_AD_MCI_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_70, X_test_data_AD_MCI_BETA_70, y_train_data_AD_MCI_BETA_70, y_test_data_AD_MCI_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_50, X_test_data_AD_MCI_BETA_50, y_train_data_AD_MCI_BETA_50, y_test_data_AD_MCI_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_30, X_test_data_AD_MCI_BETA_30, y_train_data_AD_MCI_BETA_30, y_test_data_AD_MCI_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_20, X_test_data_AD_MCI_BETA_20, y_train_data_AD_MCI_BETA_20, y_test_data_AD_MCI_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_BETA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_BETA_10, X_test_data_AD_MCI_BETA_10, y_train_data_AD_MCI_BETA_10, y_test_data_AD_MCI_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_AD_MCI_DELTA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_100, X_test_data_AD_MCI_DELTA_100, y_train_data_AD_MCI_DELTA_100, y_test_data_AD_MCI_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_70, X_test_data_AD_MCI_DELTA_70, y_train_data_AD_MCI_DELTA_70, y_test_data_AD_MCI_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_50, X_test_data_AD_MCI_DELTA_50, y_train_data_AD_MCI_DELTA_50, y_test_data_AD_MCI_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_30, X_test_data_AD_MCI_DELTA_30, y_train_data_AD_MCI_DELTA_30, y_test_data_AD_MCI_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_20, X_test_data_AD_MCI_DELTA_20, y_train_data_AD_MCI_DELTA_20, y_test_data_AD_MCI_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_DELTA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_DELTA_10, X_test_data_AD_MCI_DELTA_10, y_train_data_AD_MCI_DELTA_10, y_test_data_AD_MCI_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_100
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_100, X_test_data_AD_MCI_THETA_100, y_train_data_AD_MCI_THETA_100, y_test_data_AD_MCI_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_70
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_70, X_test_data_AD_MCI_THETA_70, y_train_data_AD_MCI_THETA_70, y_test_data_AD_MCI_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_50
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_50, X_test_data_AD_MCI_THETA_50, y_train_data_AD_MCI_THETA_50, y_test_data_AD_MCI_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_30
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_30, X_test_data_AD_MCI_THETA_30, y_train_data_AD_MCI_THETA_30, y_test_data_AD_MCI_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_20
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_20, X_test_data_AD_MCI_THETA_20, y_train_data_AD_MCI_THETA_20, y_test_data_AD_MCI_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_AD_MCI_THETA_10
y=[0]*28+[1]*22
X_train_data_AD_MCI_THETA_10, X_test_data_AD_MCI_THETA_10, y_train_data_AD_MCI_THETA_10, y_test_data_AD_MCI_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
#datasets SCI vs MCI
data_SCI_MCI_ALPHA_100= pd.concat([data_SCI_ALPHA_100,data_MCI_ALPHA_100])
data_SCI_MCI_ALPHA_70= pd.concat([data_SCI_ALPHA_70,data_MCI_ALPHA_70])
data_SCI_MCI_ALPHA_50= pd.concat([data_SCI_ALPHA_50,data_MCI_ALPHA_50])
data_SCI_MCI_ALPHA_30= pd.concat([data_SCI_ALPHA_30,data_MCI_ALPHA_30])
data_SCI_MCI_ALPHA_20= pd.concat([data_SCI_ALPHA_20,data_MCI_ALPHA_20])
data_SCI_MCI_ALPHA_10= pd.concat([data_SCI_ALPHA_10,data_MCI_ALPHA_10])
data_SCI_MCI_BETA_100= pd.concat([data_SCI_BETA_100,data_MCI_BETA_100])
data_SCI_MCI_BETA_70= pd.concat([data_SCI_BETA_70,data_MCI_BETA_70])
data_SCI_MCI_BETA_50= pd.concat([data_SCI_BETA_50,data_MCI_BETA_50])
data_SCI_MCI_BETA_30= pd.concat([data_SCI_BETA_30,data_MCI_BETA_30])
data_SCI_MCI_BETA_20= pd.concat([data_SCI_BETA_20,data_MCI_BETA_20])
data_SCI_MCI_BETA_10= pd.concat([data_SCI_BETA_10,data_MCI_BETA_10])
data_SCI_MCI_DELTA_100= pd.concat([data_SCI_DELTA_100,data_MCI_DELTA_100])
data_SCI_MCI_DELTA_70= pd.concat([data_SCI_DELTA_70,data_MCI_DELTA_70])
data_SCI_MCI_DELTA_50= pd.concat([data_SCI_DELTA_50,data_MCI_DELTA_50])
data_SCI_MCI_DELTA_30= pd.concat([data_SCI_DELTA_30,data_MCI_DELTA_30])
data_SCI_MCI_DELTA_20= pd.concat([data_SCI_DELTA_20,data_MCI_DELTA_20])
data_SCI_MCI_DELTA_10= pd.concat([data_SCI_DELTA_10,data_MCI_DELTA_10])
data_SCI_MCI_THETA_100= pd.concat([data_SCI_THETA_100,data_MCI_THETA_100])
data_SCI_MCI_THETA_70= pd.concat([data_SCI_THETA_70,data_MCI_THETA_70])
data_SCI_MCI_THETA_50= pd.concat([data_SCI_THETA_50,data_MCI_THETA_50])
data_SCI_MCI_THETA_30= pd.concat([data_SCI_THETA_30,data_MCI_THETA_30])
data_SCI_MCI_THETA_20= pd.concat([data_SCI_THETA_20,data_MCI_THETA_20])
data_SCI_MCI_THETA_10= pd.concat([data_SCI_THETA_10,data_MCI_THETA_10])

# %%
#Dataset split
X=data_SCI_MCI_ALPHA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_100, X_test_data_SCI_MCI_ALPHA_100, y_train_data_SCI_MCI_ALPHA_100, y_test_data_SCI_MCI_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_70, X_test_data_SCI_MCI_ALPHA_70, y_train_data_SCI_MCI_ALPHA_70, y_test_data_SCI_MCI_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_50, X_test_data_SCI_MCI_ALPHA_50, y_train_data_SCI_MCI_ALPHA_50, y_test_data_SCI_MCI_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_30, X_test_data_SCI_MCI_ALPHA_30, y_train_data_SCI_MCI_ALPHA_30, y_test_data_SCI_MCI_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_20, X_test_data_SCI_MCI_ALPHA_20, y_train_data_SCI_MCI_ALPHA_20, y_test_data_SCI_MCI_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_ALPHA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_ALPHA_10, X_test_data_SCI_MCI_ALPHA_10, y_train_data_SCI_MCI_ALPHA_10, y_test_data_SCI_MCI_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_100, X_test_data_SCI_MCI_BETA_100, y_train_data_SCI_MCI_BETA_100, y_test_data_SCI_MCI_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_70, X_test_data_SCI_MCI_BETA_70, y_train_data_SCI_MCI_BETA_70, y_test_data_SCI_MCI_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_50, X_test_data_SCI_MCI_BETA_50, y_train_data_SCI_MCI_BETA_50, y_test_data_SCI_MCI_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_30, X_test_data_SCI_MCI_BETA_30, y_train_data_SCI_MCI_BETA_30, y_test_data_SCI_MCI_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_20, X_test_data_SCI_MCI_BETA_20, y_train_data_SCI_MCI_BETA_20, y_test_data_SCI_MCI_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_BETA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_BETA_10, X_test_data_SCI_MCI_BETA_10, y_train_data_SCI_MCI_BETA_10, y_test_data_SCI_MCI_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_SCI_MCI_DELTA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_100, X_test_data_SCI_MCI_DELTA_100, y_train_data_SCI_MCI_DELTA_100, y_test_data_SCI_MCI_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_70, X_test_data_SCI_MCI_DELTA_70, y_train_data_SCI_MCI_DELTA_70, y_test_data_SCI_MCI_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_50, X_test_data_SCI_MCI_DELTA_50, y_train_data_SCI_MCI_DELTA_50, y_test_data_SCI_MCI_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_30, X_test_data_SCI_MCI_DELTA_30, y_train_data_SCI_MCI_DELTA_30, y_test_data_SCI_MCI_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_20, X_test_data_SCI_MCI_DELTA_20, y_train_data_SCI_MCI_DELTA_20, y_test_data_SCI_MCI_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_DELTA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_DELTA_10, X_test_data_SCI_MCI_DELTA_10, y_train_data_SCI_MCI_DELTA_10, y_test_data_SCI_MCI_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_100
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_100, X_test_data_SCI_MCI_THETA_100, y_train_data_SCI_MCI_THETA_100, y_test_data_SCI_MCI_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_70
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_70, X_test_data_SCI_MCI_THETA_70, y_train_data_SCI_MCI_THETA_70, y_test_data_SCI_MCI_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_50
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_50, X_test_data_SCI_MCI_THETA_50, y_train_data_SCI_MCI_THETA_50, y_test_data_SCI_MCI_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_30
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_30, X_test_data_SCI_MCI_THETA_30, y_train_data_SCI_MCI_THETA_30, y_test_data_SCI_MCI_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_20
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_20, X_test_data_SCI_MCI_THETA_20, y_train_data_SCI_MCI_THETA_20, y_test_data_SCI_MCI_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_MCI_THETA_10
y=[0]*22+[1]*22
X_train_data_SCI_MCI_THETA_10, X_test_data_SCI_MCI_THETA_10, y_train_data_SCI_MCI_THETA_10, y_test_data_SCI_MCI_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
#datasets SCI vs AD
data_SCI_AD_ALPHA_100= pd.concat([data_SCI_ALPHA_100,data_AD_ALPHA_100])
data_SCI_AD_ALPHA_70= pd.concat([data_SCI_ALPHA_70,data_AD_ALPHA_70])
data_SCI_AD_ALPHA_50= pd.concat([data_SCI_ALPHA_50,data_AD_ALPHA_50])
data_SCI_AD_ALPHA_30= pd.concat([data_SCI_ALPHA_30,data_AD_ALPHA_30])
data_SCI_AD_ALPHA_20= pd.concat([data_SCI_ALPHA_20,data_AD_ALPHA_20])
data_SCI_AD_ALPHA_10= pd.concat([data_SCI_ALPHA_10,data_AD_ALPHA_10])
data_SCI_AD_BETA_100= pd.concat([data_SCI_BETA_100,data_AD_BETA_100])
data_SCI_AD_BETA_70= pd.concat([data_SCI_BETA_70,data_AD_BETA_70])
data_SCI_AD_BETA_50= pd.concat([data_SCI_BETA_50,data_AD_BETA_50])
data_SCI_AD_BETA_30= pd.concat([data_SCI_BETA_30,data_AD_BETA_30])
data_SCI_AD_BETA_20= pd.concat([data_SCI_BETA_20,data_AD_BETA_20])
data_SCI_AD_BETA_10= pd.concat([data_SCI_BETA_10,data_AD_BETA_10])
data_SCI_AD_DELTA_100= pd.concat([data_SCI_DELTA_100,data_AD_DELTA_100])
data_SCI_AD_DELTA_70= pd.concat([data_SCI_DELTA_70,data_AD_DELTA_70])
data_SCI_AD_DELTA_50= pd.concat([data_SCI_DELTA_50,data_AD_DELTA_50])
data_SCI_AD_DELTA_30= pd.concat([data_SCI_DELTA_30,data_AD_DELTA_30])
data_SCI_AD_DELTA_20= pd.concat([data_SCI_DELTA_20,data_AD_DELTA_20])
data_SCI_AD_DELTA_10= pd.concat([data_SCI_DELTA_10,data_AD_DELTA_10])
data_SCI_AD_THETA_100= pd.concat([data_SCI_THETA_100,data_AD_THETA_100])
data_SCI_AD_THETA_70= pd.concat([data_SCI_THETA_70,data_AD_THETA_70])
data_SCI_AD_THETA_50= pd.concat([data_SCI_THETA_50,data_AD_THETA_50])
data_SCI_AD_THETA_30= pd.concat([data_SCI_THETA_30,data_AD_THETA_30])
data_SCI_AD_THETA_20= pd.concat([data_SCI_THETA_20,data_AD_THETA_20])
data_SCI_AD_THETA_10= pd.concat([data_SCI_THETA_10,data_AD_THETA_10])

# %%
#Dataset split
X=data_SCI_AD_ALPHA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_100, X_test_data_SCI_AD_ALPHA_100, y_train_data_SCI_AD_ALPHA_100, y_test_data_SCI_AD_ALPHA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_70, X_test_data_SCI_AD_ALPHA_70, y_train_data_SCI_AD_ALPHA_70, y_test_data_SCI_AD_ALPHA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_50, X_test_data_SCI_AD_ALPHA_50, y_train_data_SCI_AD_ALPHA_50, y_test_data_SCI_AD_ALPHA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_30, X_test_data_SCI_AD_ALPHA_30, y_train_data_SCI_AD_ALPHA_30, y_test_data_SCI_AD_ALPHA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_20, X_test_data_SCI_AD_ALPHA_20, y_train_data_SCI_AD_ALPHA_20, y_test_data_SCI_AD_ALPHA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_ALPHA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_ALPHA_10, X_test_data_SCI_AD_ALPHA_10, y_train_data_SCI_AD_ALPHA_10, y_test_data_SCI_AD_ALPHA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_100, X_test_data_SCI_AD_BETA_100, y_train_data_SCI_AD_BETA_100, y_test_data_SCI_AD_BETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_70, X_test_data_SCI_AD_BETA_70, y_train_data_SCI_AD_BETA_70, y_test_data_SCI_AD_BETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_50, X_test_data_SCI_AD_BETA_50, y_train_data_SCI_AD_BETA_50, y_test_data_SCI_AD_BETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_30, X_test_data_SCI_AD_BETA_30, y_train_data_SCI_AD_BETA_30, y_test_data_SCI_AD_BETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_20, X_test_data_SCI_AD_BETA_20, y_train_data_SCI_AD_BETA_20, y_test_data_SCI_AD_BETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_BETA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_BETA_10, X_test_data_SCI_AD_BETA_10, y_train_data_SCI_AD_BETA_10, y_test_data_SCI_AD_BETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
#Dataset split
X=data_SCI_AD_DELTA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_100, X_test_data_SCI_AD_DELTA_100, y_train_data_SCI_AD_DELTA_100, y_test_data_SCI_AD_DELTA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_70, X_test_data_SCI_AD_DELTA_70, y_train_data_SCI_AD_DELTA_70, y_test_data_SCI_AD_DELTA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_50, X_test_data_SCI_AD_DELTA_50, y_train_data_SCI_AD_DELTA_50, y_test_data_SCI_AD_DELTA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_30, X_test_data_SCI_AD_DELTA_30, y_train_data_SCI_AD_DELTA_30, y_test_data_SCI_AD_DELTA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_20, X_test_data_SCI_AD_DELTA_20, y_train_data_SCI_AD_DELTA_20, y_test_data_SCI_AD_DELTA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_DELTA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_DELTA_10, X_test_data_SCI_AD_DELTA_10, y_train_data_SCI_AD_DELTA_10, y_test_data_SCI_AD_DELTA_10 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_100
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_100, X_test_data_SCI_AD_THETA_100, y_train_data_SCI_AD_THETA_100, y_test_data_SCI_AD_THETA_100 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_70
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_70, X_test_data_SCI_AD_THETA_70, y_train_data_SCI_AD_THETA_70, y_test_data_SCI_AD_THETA_70 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_50
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_50, X_test_data_SCI_AD_THETA_50, y_train_data_SCI_AD_THETA_50, y_test_data_SCI_AD_THETA_50 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_30
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_30, X_test_data_SCI_AD_THETA_30, y_train_data_SCI_AD_THETA_30, y_test_data_SCI_AD_THETA_30 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_20
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_20, X_test_data_SCI_AD_THETA_20, y_train_data_SCI_AD_THETA_20, y_test_data_SCI_AD_THETA_20 = train_test_split(X, y, test_size=0.3, random_state=0)
X=data_SCI_AD_THETA_10
y=[0]*22+[1]*28
X_train_data_SCI_AD_THETA_10, X_test_data_SCI_AD_THETA_10, y_train_data_SCI_AD_THETA_10, y_test_data_SCI_AD_THETA_10 = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Sélaction 1 : AD vs MCI
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_100, y_train_data_AD_MCI_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_70, y_train_data_AD_MCI_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_50, y_train_data_AD_MCI_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_30, y_train_data_AD_MCI_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_20, y_train_data_AD_MCI_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_ALPHA_10, y_train_data_AD_MCI_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_100, y_train_data_AD_MCI_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_70, y_train_data_AD_MCI_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_50, y_train_data_AD_MCI_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_30, y_train_data_AD_MCI_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_20, y_train_data_AD_MCI_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_BETA_10, y_train_data_AD_MCI_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_100, y_train_data_AD_MCI_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_70, y_train_data_AD_MCI_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_50, y_train_data_AD_MCI_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_30, y_train_data_AD_MCI_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_20, y_train_data_AD_MCI_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_DELTA_10, y_train_data_AD_MCI_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_100, y_train_data_AD_MCI_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_70, y_train_data_AD_MCI_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_50, y_train_data_AD_MCI_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_30, y_train_data_AD_MCI_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_20, y_train_data_AD_MCI_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_AD_MCI_THETA_10, y_train_data_AD_MCI_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_AD_MCI = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 ad vs mci
dataset_AD_MCI_train= pd.concat([X_train_data_AD_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_AD_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_AD_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_AD_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_AD_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_AD_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_AD_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_AD_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_AD_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_AD_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_AD_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_AD_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_AD_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_AD_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_AD_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_AD_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_AD_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_AD_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_AD_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_AD_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_AD_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_AD_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_AD_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_AD_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_AD_MCI_test= pd.concat([X_test_data_AD_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_AD_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_AD_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_AD_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_AD_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_AD_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_AD_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_AD_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_AD_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_AD_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_AD_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_AD_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_AD_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_AD_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_AD_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_AD_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_AD_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_AD_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_AD_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_AD_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_AD_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_AD_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_AD_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_AD_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_AD_MCI_train.columns = data_col_names_AD_MCI
dataset_AD_MCI_test.columns = data_col_names_AD_MCI

# %%
# Sélaction 1 : SCI vs MCI
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_100, y_train_data_SCI_MCI_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_70, y_train_data_SCI_MCI_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_50, y_train_data_SCI_MCI_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_30, y_train_data_SCI_MCI_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_20, y_train_data_SCI_MCI_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_ALPHA_10, y_train_data_SCI_MCI_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_100, y_train_data_SCI_MCI_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_70, y_train_data_SCI_MCI_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_50, y_train_data_SCI_MCI_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_30, y_train_data_SCI_MCI_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_20, y_train_data_SCI_MCI_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_BETA_10, y_train_data_SCI_MCI_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_100, y_train_data_SCI_MCI_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_70, y_train_data_SCI_MCI_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_50, y_train_data_SCI_MCI_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_30, y_train_data_SCI_MCI_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_20, y_train_data_SCI_MCI_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_DELTA_10, y_train_data_SCI_MCI_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_100, y_train_data_SCI_MCI_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_70, y_train_data_SCI_MCI_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_50, y_train_data_SCI_MCI_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_30, y_train_data_SCI_MCI_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_20, y_train_data_SCI_MCI_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_MCI_THETA_10, y_train_data_SCI_MCI_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_SCI_MCI = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 SCI vs mci
dataset_SCI_MCI_train= pd.concat([X_train_data_SCI_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_SCI_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_SCI_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_SCI_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_SCI_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_SCI_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_SCI_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_SCI_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_SCI_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_SCI_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_SCI_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_SCI_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_SCI_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_SCI_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_SCI_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_SCI_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_SCI_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_SCI_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_SCI_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_SCI_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_SCI_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_SCI_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_SCI_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_SCI_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_SCI_MCI_test= pd.concat([X_test_data_SCI_MCI_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_SCI_MCI_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_SCI_MCI_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_SCI_MCI_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_SCI_MCI_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_SCI_MCI_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_SCI_MCI_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_SCI_MCI_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_SCI_MCI_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_SCI_MCI_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_SCI_MCI_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_SCI_MCI_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_SCI_MCI_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_SCI_MCI_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_SCI_MCI_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_SCI_MCI_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_SCI_MCI_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_SCI_MCI_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_SCI_MCI_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_SCI_MCI_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_SCI_MCI_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_SCI_MCI_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_SCI_MCI_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_SCI_MCI_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_SCI_MCI_train.columns = data_col_names_SCI_MCI
dataset_SCI_MCI_test.columns = data_col_names_SCI_MCI

# %%
# Sélaction 1 : SCI vs AD
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_100, y_train_data_SCI_AD_ALPHA_100)
variable1 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_70, y_train_data_SCI_AD_ALPHA_100)
variable2 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_50, y_train_data_SCI_AD_ALPHA_100)
variable3 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_30, y_train_data_SCI_AD_ALPHA_100)
variable4 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_20, y_train_data_SCI_AD_ALPHA_100)
variable5 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_ALPHA_10, y_train_data_SCI_AD_ALPHA_100)
variable6 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_100, y_train_data_SCI_AD_BETA_100)
variable7 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_70, y_train_data_SCI_AD_BETA_100)
variable8 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_50, y_train_data_SCI_AD_BETA_100)
variable9 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_30, y_train_data_SCI_AD_BETA_100)
variable10 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_20, y_train_data_SCI_AD_BETA_100)
variable11 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_BETA_10, y_train_data_SCI_AD_BETA_100)
variable12 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_100, y_train_data_SCI_AD_DELTA_100)
variable13 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_70, y_train_data_SCI_AD_DELTA_100)
variable14 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_50, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_30, y_train_data_SCI_AD_DELTA_100)
variable16 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_20, y_train_data_SCI_AD_DELTA_100)
variable17 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_DELTA_10, y_train_data_SCI_AD_DELTA_100)
variable18 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_100, y_train_data_SCI_AD_THETA_100)
variable19 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_70, y_train_data_SCI_AD_THETA_100)
variable20 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_50, y_train_data_SCI_AD_THETA_100)
variable21 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_30, y_train_data_SCI_AD_THETA_100)
variable22 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_20, y_train_data_SCI_AD_THETA_100)
variable23 = model.feature_importances_

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train_data_SCI_AD_THETA_10, y_train_data_SCI_AD_THETA_100)
variable24 = model.feature_importances_

# %%
variable1=variable1.tolist()
variable2=variable2.tolist()
variable3=variable3.tolist()
variable4=variable4.tolist()
variable5=variable5.tolist()
variable6=variable6.tolist()
variable7=variable7.tolist()
variable8=variable8.tolist()
variable9=variable9.tolist()
variable10=variable10.tolist()
variable11=variable11.tolist()
variable12=variable12.tolist()
variable13=variable13.tolist()
variable14=variable14.tolist()
variable15=variable15.tolist()
variable16=variable16.tolist()
variable17=variable17.tolist()
variable18=variable18.tolist()
variable19=variable19.tolist()
variable20=variable20.tolist()
variable21=variable21.tolist()
variable22=variable22.tolist()
variable23=variable23.tolist()
variable24=variable24.tolist()

# %%
data_col_names_SCI_AD = ['ALPHA_100_'+Elec[variable1.index(max(variable1))],
                  'ALPHA_70_'+Elec[variable2.index(max(variable2))],
                  'ALPHA_50'+Elec[variable3.index(max(variable3))],
                  'ALPHA_30'+Elec[variable4.index(max(variable4))],
                  'ALPHA_20'+Elec[variable5.index(max(variable5))],
                  'ALPHA_10'+Elec[variable6.index(max(variable6))],
                  'BETA_100_'+Elec[variable7.index(max(variable7))],
                  'BETA_70_'+Elec[variable8.index(max(variable8))],
                  'BETA_50_'+Elec[variable9.index(max(variable9))],
                  'BETA_30_'+Elec[variable10.index(max(variable10))],
                  'BETA_20_'+Elec[variable11.index(max(variable11))],
                  'BETA_10_'+Elec[variable12.index(max(variable12))],
                  'DELTA_100_'+Elec[variable13.index(max(variable13))],
                  'DELTA_70_'+Elec[variable14.index(max(variable14))],
                  'DELTA_50_'+Elec[variable15.index(max(variable15))],
                  'DELTA_30_'+Elec[variable16.index(max(variable16))],
                  'DELTA_20_'+Elec[variable17.index(max(variable17))],
                  'DELTA_10_'+Elec[variable18.index(max(variable18))],
                  'THETA_100_'+Elec[variable19.index(max(variable19))],
                  'THETA_70_'+Elec[variable20.index(max(variable20))],
                  'THETA_50_'+Elec[variable21.index(max(variable21))],
                  'THETA_30_'+Elec[variable22.index(max(variable22))],
                  'THETA_20_'+Elec[variable23.index(max(variable23))],
                  'THETA_10_'+Elec[variable24.index(max(variable24))]]

# %%
#Création dataset selection2 SCI vs AD
dataset_SCI_AD_train= pd.concat([X_train_data_SCI_AD_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_train_data_SCI_AD_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_train_data_SCI_AD_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_train_data_SCI_AD_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_train_data_SCI_AD_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_train_data_SCI_AD_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_train_data_SCI_AD_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_train_data_SCI_AD_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_train_data_SCI_AD_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_train_data_SCI_AD_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_train_data_SCI_AD_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_train_data_SCI_AD_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_train_data_SCI_AD_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_train_data_SCI_AD_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_train_data_SCI_AD_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_train_data_SCI_AD_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_train_data_SCI_AD_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_train_data_SCI_AD_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_train_data_SCI_AD_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_train_data_SCI_AD_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_train_data_SCI_AD_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_train_data_SCI_AD_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_train_data_SCI_AD_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_train_data_SCI_AD_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)

dataset_SCI_AD_test= pd.concat([X_test_data_SCI_AD_ALPHA_100.iloc[:,variable1.index(max(variable1))], 
                                X_test_data_SCI_AD_ALPHA_70.iloc[:,variable2.index(max(variable2))],
                                X_test_data_SCI_AD_ALPHA_50.iloc[:,variable3.index(max(variable3))],
                                X_test_data_SCI_AD_ALPHA_30.iloc[:,variable4.index(max(variable4))], 
                                X_test_data_SCI_AD_ALPHA_20.iloc[:,variable5.index(max(variable5))],
                                X_test_data_SCI_AD_ALPHA_10.iloc[:,variable6.index(max(variable6))],
                                X_test_data_SCI_AD_BETA_100.iloc[:,variable7.index(max(variable7))],
                                X_test_data_SCI_AD_BETA_70.iloc[:,variable8.index(max(variable8))],
                                X_test_data_SCI_AD_BETA_50.iloc[:,variable9.index(max(variable9))],
                                X_test_data_SCI_AD_BETA_30.iloc[:,variable10.index(max(variable10))],
                                X_test_data_SCI_AD_BETA_20.iloc[:,variable11.index(max(variable11))],
                                X_test_data_SCI_AD_BETA_10.iloc[:,variable12.index(max(variable12))],
                                X_test_data_SCI_AD_DELTA_100.iloc[:,variable13.index(max(variable13))],
                                X_test_data_SCI_AD_DELTA_70.iloc[:,variable14.index(max(variable14))],
                                X_test_data_SCI_AD_DELTA_50.iloc[:,variable15.index(max(variable15))],
                                X_test_data_SCI_AD_DELTA_30.iloc[:,variable16.index(max(variable16))],
                                X_test_data_SCI_AD_DELTA_20.iloc[:,variable17.index(max(variable17))],
                                X_test_data_SCI_AD_DELTA_10.iloc[:,variable18.index(max(variable18))],
                                X_test_data_SCI_AD_THETA_100.iloc[:,variable19.index(max(variable19))],
                                X_test_data_SCI_AD_THETA_70.iloc[:,variable20.index(max(variable20))],
                                X_test_data_SCI_AD_THETA_50.iloc[:,variable21.index(max(variable21))],
                                X_test_data_SCI_AD_THETA_30.iloc[:,variable22.index(max(variable22))],
                                X_test_data_SCI_AD_THETA_20.iloc[:,variable23.index(max(variable23))],
                                X_test_data_SCI_AD_THETA_10.iloc[:,variable24.index(max(variable24))]],axis=1)
dataset_SCI_AD_train.columns = data_col_names_SCI_AD
dataset_SCI_AD_test.columns = data_col_names_SCI_AD

# %% [raw]
# #Seconde selesction
# #sondes
# sonde1 = np.random.rand(dataset_AD_MCI_train.shape[0])
# sonde2 = np.random.rand(dataset_SCI_MCI_train.shape[0])
# sonde3 = np.random.rand(dataset_SCI_AD_train.shape[0])

# %% [raw]
# dataset_AD_MCI_train['Sonde']= sonde1
# dataset_SCI_MCI_train['Sonde']= sonde2
# dataset_SCI_AD_train['Sonde']= sonde3

# %%
#fonction de selection sonde
def selector (importance, variables, nb):
    t=[]
    for i in range(nb):
        t.append(variables[importance[i]])
        print(variables[importance[i]])
    return t

# %%
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(dataset_AD_MCI_train, y_train_data_AD_MCI_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_AD_MCI,10)
final_train_dataset_AD_MCI_cfd = dataset_AD_MCI_train[t]
final_test_dataset_AD_MCI_cfd = dataset_AD_MCI_test[t]
final_y_train_AD_MCI= y_train_data_AD_MCI_DELTA_100
final_y_test_AD_MCI= y_test_data_AD_MCI_DELTA_100
# Out:
# BETA_20_Elec22
# DELTA_50_Elec9
# DELTA_70_Elec9
# ALPHA_70_Elec21
# THETA_50_Elec9
# DELTA_10_Elec9
# BETA_70_Elec27
# ALPHA_30Elec30
# BETA_100_Elec1
# DELTA_20_Elec15

# %%
model = ExtraTreesClassifier(n_estimators=20)
model.fit(dataset_SCI_MCI_train, y_train_data_SCI_MCI_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_SCI_MCI,10)
final_train_dataset_SCI_MCI_cfd = dataset_SCI_MCI_train[t]
final_test_dataset_SCI_MCI_cfd = dataset_SCI_MCI_test[t]
final_y_train= y_train_data_SCI_MCI_DELTA_100
final_y_test= y_test_data_SCI_MCI_DELTA_100
# Out:
# ALPHA_100_Elec11
# ALPHA_50Elec18
# DELTA_30_Elec17
# THETA_70_Elec7
# BETA_50_Elec22
# ALPHA_10Elec23
# ALPHA_30Elec11
# ALPHA_20Elec11
# DELTA_10_Elec9
# THETA_30_Elec12

# %%
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(dataset_SCI_AD_train, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,data_col_names_SCI_AD,10)
final_train_dataset_SCI_AD_cfd = dataset_SCI_AD_train[t]
final_test_dataset_SCI_AD_cfd = dataset_SCI_AD_test[t]
final_y_train= y_train_data_SCI_AD_DELTA_100
final_y_test= y_test_data_SCI_AD_DELTA_100
# Out:
# ALPHA_100_Elec16
# ALPHA_20Elec11
# DELTA_50_Elec29
# DELTA_10_Elec29
# DELTA_30_Elec29
# BETA_100_Elec15
# THETA_30_Elec4
# ALPHA_10Elec11
# THETA_50_Elec13
# DELTA_20_Elec29

# %%
x_train_data_all_AD_MCI= pd.concat([final_train_dataset_AD_MCI_nb_co,final_train_dataset_AD_MCI_moy,final_train_dataset_AD_MCI_cfd], axis = 1)
x_test_data_all_AD_MCI= pd.concat([final_test_dataset_AD_MCI_nb_co,final_test_dataset_AD_MCI_moy,final_test_dataset_AD_MCI_cfd], axis = 1)

# %%
x_train_data_all_SCI_MCI= pd.concat([final_train_dataset_SCI_MCI_nb_co,final_train_dataset_SCI_MCI_moy,final_train_dataset_SCI_MCI_cfd], axis = 1)
x_test_data_all_SCI_MCI= pd.concat([final_test_dataset_SCI_MCI_nb_co,final_test_dataset_SCI_MCI_moy,final_test_dataset_SCI_MCI_cfd], axis = 1)

# %%
x_train_data_all_SCI_AD= pd.concat([final_train_dataset_SCI_AD_nb_co,final_train_dataset_SCI_AD_moy,final_train_dataset_SCI_AD_cfd], axis = 1)
x_test_data_all_SCI_AD= pd.concat([final_test_dataset_SCI_AD_nb_co,final_test_dataset_SCI_AD_moy,final_test_dataset_SCI_AD_cfd], axis = 1)

# %%
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(x_train_data_all_AD_MCI, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,list(x_train_data_all_AD_MCI.columns),5)
final_x_train_data_all_AD_MCI = x_train_data_all_AD_MCI[t]
final_x_test_data_all_AD_MCI = x_test_data_all_AD_MCI[t]
final_y_train_AD_MCI= y_train_data_AD_MCI_DELTA_100
final_y_test_AD_MCI= y_test_data_AD_MCI_DELTA_100  ##changed y_train with y_test
# Out:
# THETA_70_Elec10
# DELTA_20_Elec9
# DELTA_70_Elec16
# BETA_10_Elec12
# THETA_50_Elec7

# %%
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(x_train_data_all_SCI_MCI, y_train_data_SCI_MCI_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,list(x_train_data_all_SCI_MCI.columns),5)

final_x_train_data_all_SCI_MCI = x_train_data_all_SCI_MCI[t]
final_x_test_data_all_SCI_MCI = x_test_data_all_SCI_MCI[t]
final_y_train_SCI_MCI= y_train_data_SCI_MCI_DELTA_100
final_y_test_SCI_MCI= y_test_data_SCI_MCI_DELTA_100
# Out:
# THETA_10_Elec7
# ALPHA_100_Elec11
# BETA_30_Elec4
# ALPHA_20Elec11
# ALPHA_50Elec11

# %%
model = ExtraTreesClassifier(n_estimators=20,max_depth=5)
model.fit(x_train_data_all_SCI_AD, y_train_data_SCI_AD_DELTA_100)
variable15 = model.feature_importances_
indices = np.argsort(variable15)[::-1]
t=selector(indices,list(x_train_data_all_SCI_AD.columns),5)
final_x_train_data_all_SCI_AD = x_train_data_all_SCI_AD[t]
final_x_test_data_all_SCI_AD = x_test_data_all_SCI_AD[t]
final_y_train_SCI_AD= y_train_data_SCI_AD_DELTA_100
final_y_test_SCI_AD= y_test_data_SCI_AD_DELTA_100
# Out:
# ALPHA_10Elec11
# DELTA_20_Elec27
# ALPHA_50Elec15
# ALPHA_20Elec11
# ALPHA_100_Elec16

# %%
#data_sci_ad
data_sci_ad = pd.concat([final_x_train_data_all_SCI_AD,final_x_test_data_all_SCI_AD])
labels_sci_ad = final_y_train_SCI_AD+final_y_test_SCI_AD

#data_ad_mci
data_ad_mci = pd.concat([final_x_train_data_all_AD_MCI,final_x_test_data_all_AD_MCI])
labels_ad_mci = y_train_data_AD_MCI_DELTA_100 +y_test_data_AD_MCI_DELTA_100 
#data_sci_mci
data_sci_mci = pd.concat([final_x_train_data_all_SCI_MCI,final_x_test_data_all_SCI_MCI])
labels_sci_mci = final_y_train_SCI_MCI+final_y_test_SCI_MCI

# %%
svm_model = svm.SVC(kernel = 'poly',gamma = 'auto')
num_folds = 10
loocv = LeaveOneOut()
svm_scores = cross_val_score(svm_model, data_ad_mci,labels_ad_mci, cv=loocv)
y_pred = cross_val_predict(svm_model, data_ad_mci,labels_ad_mci, cv=loocv)
print('accuaracy of SVM on AD_MCI',svm_scores.mean())
cnf_matrix_AD_MCI = confusion_matrix(labels_ad_mci,y_pred)
print('matrice de confusion: ',cnf_matrix_AD_MCI)
print('-----------------------------------------------------------------')

print('specificity:',cnf_matrix_AD_MCI[1,1]/(cnf_matrix_AD_MCI[1,1] + cnf_matrix_AD_MCI[0,1]))
print('sensitivity:',cnf_matrix_AD_MCI[0,0]/(cnf_matrix_AD_MCI[0,0] + cnf_matrix_AD_MCI[1,0]))

svm_scores = cross_val_score(svm_model, data_sci_mci,labels_sci_mci, cv=loocv)
y_pred = cross_val_predict(svm_model, data_sci_mci,labels_sci_mci, cv=loocv)
print('accuaracy of SVM on SCI_MCI',svm_scores.mean())
cnf_matrix_SCI_MCI = confusion_matrix(labels_sci_mci,y_pred)
print('matrice de confusion:',cnf_matrix_SCI_MCI)
print('specificity:',cnf_matrix_SCI_MCI[1,1]/(cnf_matrix_SCI_MCI[1,1] + cnf_matrix_SCI_MCI[0,1]))
print('sensitivity:',cnf_matrix_SCI_MCI[0,0]/(cnf_matrix_SCI_MCI[0,0] + cnf_matrix_SCI_MCI[1,0]))
print('-----------------------------------------------------------------')

svm_scores = cross_val_score(svm_model, data_sci_ad,labels_sci_ad, cv=loocv)
y_pred = cross_val_predict(svm_model, data_sci_ad,labels_sci_ad, cv=loocv)
print('accuaracy of SVM on SCI_AD',svm_scores.mean())
cnf_matrix_SCI_AD = confusion_matrix(labels_sci_ad,y_pred)
print('matrice de confusion:',cnf_matrix_SCI_AD)
print('specificity:',cnf_matrix_SCI_AD[1,1]/(cnf_matrix_SCI_AD[1,1] + cnf_matrix_SCI_AD[0,1]))
print('sensitivity:',cnf_matrix_SCI_AD[0,0]/(cnf_matrix_SCI_AD[0,0] + cnf_matrix_SCI_AD[1,0]))
print('-----------------------------------------------------------------')
# Out:
# accuaracy of SVM on AD_MCI 0.74
# matrice de confusion:  [[23  5]
#  [ 8 14]]
# -----------------------------------------------------------------
# specificity: 0.7368421052631579
# sensitivity: 0.7419354838709677
# accuaracy of SVM on SCI_MCI 0.7272727272727273
# matrice de confusion: [[16  6]
#  [ 6 16]]
# specificity: 0.7272727272727273
# sensitivity: 0.7272727272727273
# -----------------------------------------------------------------
# accuaracy of SVM on SCI_AD 0.72
# matrice de confusion: [[15  7]
#  [ 7 21]]
# specificity: 0.75
# sensitivity: 0.6818181818181818
# -----------------------------------------------------------------

# %%
knn = KNeighborsClassifier()


num_folds = 10
loocv = LeaveOneOut()
model = knn

knn_scores = cross_val_score(model, data_ad_mci,labels_ad_mci, cv=loocv)
y_pred = cross_val_predict(model, data_ad_mci,labels_ad_mci, cv=loocv)
print('accuaracy of KNN on AD_MCI',knn_scores.mean())
cnf_matrix_AD_MCI = confusion_matrix(labels_ad_mci,y_pred)
print('matrice de confusion: ',cnf_matrix_AD_MCI)
print('specificity:',cnf_matrix_AD_MCI[1,1]/(cnf_matrix_AD_MCI[1,1] + cnf_matrix_AD_MCI[0,1]))
print('sensitivity:',cnf_matrix_AD_MCI[0,0]/(cnf_matrix_AD_MCI[0,0] + cnf_matrix_AD_MCI[1,0]))
print('-----------------------------------------------------------------')

knn_scores = cross_val_score(model, data_sci_mci,labels_sci_mci, cv=loocv)
y_pred = cross_val_predict(model, data_sci_mci,labels_sci_mci, cv=loocv)
print('accuaracy of KNN on SCI_MCI',knn_scores.mean())
cnf_matrix_SCI_MCI = confusion_matrix(labels_sci_mci,y_pred)
print('matrice de confusion:',cnf_matrix_SCI_MCI)
print('specificity:',cnf_matrix_SCI_MCI[1,1]/(cnf_matrix_SCI_MCI[1,1] + cnf_matrix_SCI_MCI[0,1]))
print('sensitivity:',cnf_matrix_SCI_MCI[0,0]/(cnf_matrix_SCI_MCI[0,0] + cnf_matrix_SCI_MCI[1,0]))
print('-----------------------------------------------------------------')

knn_scores = cross_val_score(model, data_sci_ad,labels_sci_ad, cv=loocv)
y_pred = cross_val_predict(model, data_sci_ad,labels_sci_ad, cv=loocv)
print('accuaracy of KNN on SCI_AD',knn_scores.mean())
cnf_matrix_SCI_AD = confusion_matrix(labels_sci_ad,y_pred)
print('matrice de confusion:',cnf_matrix_SCI_AD)
print('specificity:',cnf_matrix_SCI_AD[1,1]/(cnf_matrix_SCI_AD[1,1] + cnf_matrix_SCI_AD[0,1]))
print('sensitivity:',cnf_matrix_SCI_AD[0,0]/(cnf_matrix_SCI_AD[0,0] + cnf_matrix_SCI_AD[1,0]))
print('-----------------------------------------------------------------')
# Out:
# accuaracy of KNN on AD_MCI 0.64
# matrice de confusion:  [[15 13]
#  [ 5 17]]
# specificity: 0.5666666666666667
# sensitivity: 0.75
# -----------------------------------------------------------------
# accuaracy of KNN on SCI_MCI 0.75
# matrice de confusion: [[15  7]
#  [ 4 18]]
# specificity: 0.72
# sensitivity: 0.7894736842105263
# -----------------------------------------------------------------
# accuaracy of KNN on SCI_AD 0.72
# matrice de confusion: [[14  8]
#  [ 6 22]]
# specificity: 0.7333333333333333
# sensitivity: 0.7
# -----------------------------------------------------------------
